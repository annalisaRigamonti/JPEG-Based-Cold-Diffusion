# %% [markdown]
# # Reconstructing images
# to change the model, overwrite:
# - MODEL variable;
# - QUANT_TABLES variable if necessary;
# - the degradation function.

# %% [markdown]
# ## Importing and Loading

# %%
! pip install kornia
! pip install torch_dct
! pip install torchgeometry
# Out:
# Collecting kornia
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting kornia-rs>=0.1.9 (from kornia)
#   Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from kornia) (26.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from kornia) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->kornia) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.3 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 84.3 MB/s eta 0:00:00
# Installing collected packages: kornia-rs, kornia
# Successfully installed kornia-0.8.3 kornia-rs-0.1.14
# Collecting torch_dct
#   Downloading torch_dct-0.1.6-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from torch_dct) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=0.4.1->torch_dct) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=0.4.1->torch_dct) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=0.4.1->torch_dct) (3.0.3)
# Downloading torch_dct-0.1.6-py3-none-any.whl (5.1 kB)
# Installing collected packages: torch_dct
# Successfully installed torch_dct-0.1.6
# Collecting torchgeometry
#   Downloading torchgeometry-0.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from torchgeometry) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.0.0->torchgeometry) (1.8.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.0.0->torchgeometry) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.0.0->torchgeometry) (3.0.3)
# Downloading torchgeometry-0.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: torchgeometry
# Successfully installed torchgeometry-0.1.2

# %%
# IMPORTS
import random
from PIL import Image
import torchvision.transforms as T
import matplotlib.pyplot as plt
import torch
import os
import sys
from pathlib import Path

import kornia
import torch_dct as dct

from types import MethodType
import gc


from torch._prims_common import check

from collections import OrderedDict
import copy

# reconstruction
import os
import glob
import torch
from PIL import Image
import torchvision.transforms as T
import torchvision.utils as vutils

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Base path
BASE_DIR = "/content/drive/MyDrive/Colab Notebooks/tesi/" if 'google.colab' in str(get_ipython()) else "."
MODEL = "03_dequant-quant_longer2"
NAME = "03_recon_jpeg_dequant-quant_longer2"

# Directories
ZIP_PATH = os.path.join(BASE_DIR, "data", "img_align_celeba.zip")
LOCAL_DATA_ROOT = "/content/raw_data"
SRC_C_D = os.path.join(BASE_DIR, "src", "Cold-Diffusion-Models", "resolution-diffusion-pytorch", "resolution_diffusion_pytorch")
QUANT_TABLES = os.path.join(BASE_DIR, "assets/dequant-quant3_qt.pt")


CHECKPOINT_DIR = os.path.join(BASE_DIR, "checkpoints", "coeff_quantized", "1_final_degradation_function", MODEL)
TRAINED_MODEL_DIR = os.path.join(BASE_DIR, "trained_models", "cold_diffusion", "coeff_quantized", "1_final_degradation_function", MODEL)

OUTPUT_DIR = os.path.join(BASE_DIR, "outputs", "reconstructions", "coeff_quantized", NAME)

# restoration
VAE_FACES_DIR = os.path.join(BASE_DIR, 'data', 'generated_images1')

# importing the models
if SRC_C_D not in sys.path:
    sys.path.append(SRC_C_D)

# Folder creation
for path in [CHECKPOINT_DIR, OUTPUT_DIR, TRAINED_MODEL_DIR]:
    os.makedirs(path, exist_ok=True)

# %%
tot_generated_images = 100

# %%
from resolution_diffusion_pytorch import Unet, GaussianDiffusion, Trainer

dataset_path = os.path.join(LOCAL_DATA_ROOT, "img_align_celeba")
model_path = os.path.join(TRAINED_MODEL_DIR, f'{MODEL}.pt')
quant_tables = torch.load(QUANT_TABLES)

# %% [markdown]
# ## degradation function

# %%
# State shared between consecutive steps - valid just as long as q_sample lasts
_dct_state = {
    'coeffs': None,     # real DCT coefficients (not quantized) - updated at each step
    'step': -1,         # last step applied
}

def get_quant_table_tensor(step, device):
    lum  = quant_tables[f'step{step}_luminance'].to(device)    # [8, 8]
    chrom = quant_tables[f'step{step}_chrominance'].to(device) # [8, 8]
    return lum, chrom

def img_to_dct_blocks(img_batch):
    """
    Pixel space [-1,1] -> DCT coefficients, frequency space.
    Returns (blocks_dct, bH, bW) where blocks_dct shape [B, C, bH*bW, 8, 8].
    """
    B, C, H, W = img_batch.shape
    x = (img_batch + 1) * 0.5                          # [-1,1] -> [0,1]
    x_ycbcr = kornia.color.rgb_to_ycbcr(x)             # [0,1] YCbCr
    x_255 = x_ycbcr * 255.0                            # [0,255]

    blocks = x_255.unfold(2, 8, 8).unfold(3, 8, 8)     # [B,C,bH,bW,8,8]
    bH, bW = blocks.shape[2], blocks.shape[3]
    blocks_flat = blocks.contiguous().reshape(B, C, bH * bW, 8, 8)
    dct_blocks = dct.dct_2d(blocks_flat, norm='ortho')  # [B,C,bH*bW,8,8]
    return dct_blocks, bH, bW

def dct_blocks_to_img(dct_blocks, bH, bW, B, C, H, W):
    """
    DCT coefficients → pixel space [-1,1].
    """
    result_flat = dct.idct_2d(dct_blocks, norm='ortho')
    result = result_flat.reshape(B, C, bH, bW, 8, 8)
    result = result.permute(0, 1, 2, 4, 3, 5).contiguous().reshape(B, C, H, W)
    result_01 = (result / 255.0).clamp(0, 1)
    result_rgb = kornia.color.ycbcr_to_rgb(result_01)
    return (result_rgb * 2 - 1).clamp(-1, 1)

def quantize_dct(dct_blocks, q_lum, q_chrom):
    """
    Quantizes DCT coefficients with luma/chroma tables.
    Returns quantized coefficients, not divided by q yet.
    """
    q_lum   = q_lum.unsqueeze(0).unsqueeze(0)    # [1,1,8,8]
    q_chrom = q_chrom.unsqueeze(0).unsqueeze(0)  # [1,1,8,8]
    out = dct_blocks.clone()
    out[:, 0:1] = torch.round(dct_blocks[:, 0:1] / q_lum)   * q_lum
    # out[:, 1:3] = torch.round(dct_blocks[:, 1:3] / q_chrom) * q_chrom
    return out

def dequantize_dct(dct_blocks, q_lum, q_chrom):
    """
    Dequantizes DCT coefficients with luma/chroma tables.
    Thanks to the saved original coefficients,
    and since the current coefficients are already real,
    this funtion does nothing.
    """
    return dct_blocks

def jpeg_degradation(img_batch, step):
    """
    Cumulative JPEG degradation in frequence space

    - step = 0: no degradation, resets state
    - step = 1: DCT from zero on original image -> quantize with table [1]
    - step > 1: quantizes with table [t] -> update state
    """
    device = img_batch.device
    current_step = step.item() if torch.is_tensor(step) else step

    if current_step == 0:
        # Reset state, no degradation
        _dct_state['coeffs'] = None
        _dct_state['step'] = -1
        return img_batch

    B, C, H, W = img_batch.shape

    if current_step == 1 or _dct_state['coeffs'] is None:
        # The first step compute DCT coefficients
        dct_blocks, bH, bW = img_to_dct_blocks(img_batch)
        _dct_state['original_dct'] = dct_blocks.clone()  # save original
        _dct_state['bH'] = bH
        _dct_state['bW'] = bW
    else:
        # Other steps: always starts from x0 for applying the new table
        dct_blocks = _dct_state['original_dct'].to(device)
        bH = _dct_state['bH']
        bW = _dct_state['bW']

    # Apply current step table directly on original coefficients
    q_lum, q_chrom = get_quant_table_tensor(current_step, device)
    quantized = quantize_dct(dct_blocks, q_lum, q_chrom)

    # Update the state
    _dct_state['coeffs'] = quantized
    _dct_state['step'] = current_step

    return dct_blocks_to_img(quantized, bH, bW, B, C, H, W)

# %%
# Out Of Memory problems
torch.cuda.synchronize()
gc.collect()
torch.cuda.empty_cache()
print(f"Free GPU memory: {torch.cuda.mem_get_info()[0] / 1e9:.2f} GB")

def new_sample(self, batch_size=16, img=None, t=None):
    '''
    Images direct reconstruction
    '''

    if t is None:
        t = self.num_timesteps

    xt = img # image at maximum degraded step

    direct_recons = None

    while t:
        with torch.no_grad():
            step = torch.full((batch_size,), t - 1, dtype=torch.long).cuda()
            # Denoise x_t to get an estimate of x_0 (denoted as 'x')
            x = self.denoise_fn(img, step)

            if self.train_routine == 'Final':
                if direct_recons is None:
                    direct_recons = x

                if self.sampling_routine == 'default':
                    img = jpeg_degradation(x, t - 1)

                elif self.sampling_routine == 'x0_step_down':
                    x_times = jpeg_degradation(x, t)
                    x_times_sub_1 = jpeg_degradation(x, t - 1)
                    img = img - x_times + x_times_sub_1

        t -= 1

    return xt, direct_recons, img
# Out:
# Free GPU memory: 15.53 GB

# %% [markdown]
# ## Cold Diffusion model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
IMG_SIZE = 128

def find_last_checkpoint(save_folder):
    path = os.path.join(save_folder, f'model.pt')
    if os.path.exists(path):
        return path
    return None

# %%
# --- CONFIGURATION ---
class Args:
    time_steps = 9
    train_steps = 30000
    save_folder = OUTPUT_DIR
    data_path = dataset_path
    checkpoint_path = CHECKPOINT_DIR
    load_path = find_last_checkpoint(checkpoint_path)
    train_routine = 'Final'
    resolution_routine = 'Incremental'
    sampling_routine = 'x0_step_down'
    image_size = IMG_SIZE
    channels = 3

args = Args()

# --- MODEL INITIALIZATION ---
model = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8),
    channels = args.channels
).cuda()

diffusion = GaussianDiffusion(
    model,
    image_size = args.image_size,
    device_of_kernel = 'cuda',
    channels = args.channels,
    timesteps = args.time_steps,
    loss_type = 'l1',
    resolution_routine = args.resolution_routine,
    train_routine = args.train_routine,
    sampling_routine = args.sampling_routine
).cuda()

if torch.cuda.device_count() > 1:
    diffusion = torch.nn.DataParallel(diffusion)
# Out:
# Is Time embed used ?  True

# %% [markdown]
# <!-- ## Resources
# [] -->

# %%
trained_model = torch.load(model_path)

new_state_dict = OrderedDict()
for k, v in trained_model.items():
    new_key = k.replace('module.', '', 1)
    new_state_dict[new_key] = v

if isinstance(diffusion, torch.nn.DataParallel):
    diffusion.module.load_state_dict(new_state_dict)
    print("Model loaded into DataParallel wrapper.")
else:
    diffusion.load_state_dict(new_state_dict)
    print("Model loaded directly.")

# Create ema_model as a deep copy of the loaded diffusion model
# This bypasses the Trainer initialization which requires a dataset
ema_model = copy.deepcopy(diffusion)
print("EMA model created as a deep copy.")

# OVERWRITING
if isinstance(diffusion, torch.nn.DataParallel):
    diffusion.module.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]
    ema_model.module.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]
else:
    diffusion.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]
    ema_model.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]


# Patch the `sample` method for both diffusion and ema_model
# Get the inner models if DataParallel
inner_diffusion = diffusion.module if isinstance(diffusion, torch.nn.DataParallel) else diffusion
inner_ema_model = ema_model.module if isinstance(ema_model, torch.nn.DataParallel) else ema_model

# Apply the new_sample patch to the `sample` method (instead of q_sample)
inner_diffusion.sample = MethodType(new_sample, inner_diffusion)
inner_ema_model.sample = MethodType(new_sample, inner_ema_model)


# Set models to evaluation mode
diffusion.eval()
ema_model.eval()
print("Model and EMA model loaded, patched, and set to eval mode.")
# Out:
# Model loaded directly.
# EMA model created as a deep copy.
# Model and EMA model loaded, patched, and set to eval mode.

# %% [markdown]
# ## Reconstruction
# Integrates the synthetic faces generated by the VAE ('DC blocks', 128x128) into the Cold Diffusion pipeline, using the trained model.
#
# I do not use directly the `sample()` function because it expects the original image, x_0, and degradates it to get x_t. The generated images are already equivalent to step x_t.
#
# To get the same result, it is possible to call directly the `denoise_fn(img, step=t-1)`.

# %%
IMG_SIZE = 128            # must be the same as in the trained model
TIME_STEPS = 9            # must be the same as in the trained model
BATCH_SIZE = 64

# %%
os.makedirs(OUTPUT_DIR, exist_ok=True)

# loading images
to_tensor = T.Compose([
    T.Resize((IMG_SIZE, IMG_SIZE)),    # for safety. should be no-op
    T.ToTensor(),                      # -> [0,1]
])

# %%
def load_batch_as_minus1_1(paths):
    imgs = [to_tensor(Image.open(p).convert('RGB')) for p in paths]
    batch = torch.stack(imgs, dim=0)   # [B,3,H,W] in [0,1]
    batch = batch * 2 - 1              # -> [-1,1], range for denoise_fn/Unet
    return batch.cuda()

def save_reconstructions(tensor_minus1_1, start_idx, dir_):
    imgs = (tensor_minus1_1.clamp(-1, 1) + 1) / 2   # -> [0,1] per il salvataggio
    for i, img in enumerate(imgs):
        vutils.save_image(img, os.path.join(dir_, f'recon_{start_idx + i:06d}.jpg'))

# %% [markdown]
# Reconstruction functions

# %%
# equivalent to direct_recon
def reconstruct_direct(diffusion_model, img_batch, time_steps):
    """
    Returns the direct reconstruction of the image.
    """
    batch_size = img_batch.shape[0]
    step = torch.full((batch_size,), time_steps - 1, dtype=torch.long).cuda()
    with torch.no_grad():
        direct_recons = diffusion_model.denoise_fn(img_batch, step)
    return direct_recons

def reconstruct_indirect(diffusion_model, img_batch, time_steps):
  with torch.no_grad():
    batch_size_val = img_batch.shape[0]
    # note: here the images in img_batch are already at maximum degradation step,
    # no further degradation is needed
    xt, direct_recons, restored = diffusion_model.sample(
        batch_size=batch_size_val,
        img=img_batch,
        t=time_steps
    )
    return restored

# %% [markdown]
# Reconstructing the images:

# %%
def run(diffusion_model, num_images_to_process = 10, direct = True, output_directory=OUTPUT_DIR):
    paths = sorted(glob.glob(os.path.join(VAE_FACES_DIR, '*.jpg')))
    print(f'Found {len(paths)} syntetic images to reconstruct')

    for start in range(0, min(len(paths), num_images_to_process), BATCH_SIZE):
        batch_paths = paths[start:start + BATCH_SIZE]
        img_batch = load_batch_as_minus1_1(batch_paths)

        if direct:
          direct_recons = reconstruct_direct(diffusion_model, img_batch, TIME_STEPS)
        else:
          direct_recons = reconstruct_indirect(diffusion_model, img_batch, TIME_STEPS)

        save_reconstructions(direct_recons.cpu(), start, output_directory)
        del img_batch, direct_recons
        torch.cuda.empty_cache()

    print(f'Reconstructions saved in: {output_directory}')

# %%
def plot_some_reconstructions(num_images_to_plot = 4, output_directory = OUTPUT_DIR, direct = True):
    # Get a list of all reconstructed image paths
    reconstructed_image_paths = sorted(glob.glob(os.path.join(output_directory, 'recon_*.jpg')))

    # Get a list of original degraded image paths (these are the inputs to the reconstruction)
    original_image_paths = sorted(glob.glob(os.path.join(VAE_FACES_DIR, '*.jpg')))

    # Select the first 'num_images_to_plot' images from both lists
    images_to_display_recon = reconstructed_image_paths[:num_images_to_plot]
    images_to_display_orig = original_image_paths[:num_images_to_plot]

    if not images_to_display_recon or not images_to_display_orig:
        print(f"No reconstructed or original images found in {output_directory} or {VAE_FACES_DIR}")
    else:
        fig, axes = plt.subplots(2, num_images_to_plot, figsize=(num_images_to_plot * 4, 8))
        if direct:
            fig.suptitle('Original Degraded vs. Reconstructed Images - direct', fontsize=16)
        else:
            fig.suptitle('Original Degraded vs. Reconstructed Images - indirect', fontsize=16)

        for i in range(num_images_to_plot):
            # Plot original degraded image
            orig_img = Image.open(images_to_display_orig[i])
            axes[0, i].imshow(orig_img)
            axes[0, i].set_title(f'Original {i+1}')
            axes[0, i].axis('off')

            # Plot reconstructed image
            recon_img = Image.open(images_to_display_recon[i])
            axes[1, i].imshow(recon_img)
            axes[1, i].set_title(f'Recon {i+1}')
            axes[1, i].axis('off')

        plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Adjust layout to prevent title overlap
        plt.show()

# %% [markdown]
# ### Reconstruction
# Finally, now the call to the run function performs reconstruction of the degradated images, previously generated by the VAE.
#
# Both direct and undirect methods can be used. Both will be plotted for visual comparison.

# %%
output_directory_dir = os.path.join(OUTPUT_DIR, "direct_recon")
os.makedirs(output_directory_dir, exist_ok=True)

output_directory_indir = os.path.join(OUTPUT_DIR, "indirect_recon")
os.makedirs(output_directory_indir, exist_ok=True)

run(ema_model, num_images_to_process=tot_generated_images, direct=True, output_directory=output_directory_dir)

run(ema_model, num_images_to_process=tot_generated_images, direct=False, output_directory=output_directory_indir)
# Out:
# Found 1000 syntetic images to reconstruct
# Reconstructions saved in: /content/drive/MyDrive/Colab Notebooks/tesi/outputs/reconstructions/coeff_quantized/03_recon_jpeg_dequant-quant_longer2/direct_recon
# Found 1000 syntetic images to reconstruct
# Reconstructions saved in: /content/drive/MyDrive/Colab Notebooks/tesi/outputs/reconstructions/coeff_quantized/03_recon_jpeg_dequant-quant_longer2/indirect_recon

# %%
plot_some_reconstructions(output_directory=output_directory_dir, direct=True)

# %%
plot_some_reconstructions(output_directory=output_directory_indir, direct=False)
