# %% [markdown]
# # Contents
# This notebook uses the same configuration as the first, but the degradation steps are 20 instead of 10.

# %%
TRAIN = False
TEST = True

# %% [markdown]
# # Imports
# Installing libraries, importing them

# %%
! pip install torch torchvision
! pip install matplotlib
! pip install comet_ml
! pip install einops
! pip install torchgeometry
! pip install jpegio
! pip install torch_dct
! pip install kornia
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (0.26.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting comet_ml
#   Downloading comet_ml-3.58.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-1.2.14-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (4.26.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.32.4)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (13.9.4)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.68.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from comet_ml) (75.2.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.13/dist-packages (from comet_ml) (4.1.1)
# Requirement already satisfied: urllib3>=1.26.8 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.3.0)
# Collecting wurlitzer>=1.0.2 (from comet_ml)
#   Downloading wurlitzer-3.1.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2026.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.3.2->comet_ml) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.3.2->comet_ml) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.58.6-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.7/829.7 kB 36.1 MB/s eta 0:00:00
# Downloading dulwich-1.2.14-cp313-cp313-manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 91.7 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-py3-none-any.whl (27 kB)
# Downloading wurlitzer-3.1.1-py3-none-any.whl (8.6 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, wurlitzer, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.4.1
#     Uninstalling python-box-7.4.1:
#       Successfully uninstalled python-box-7.4.1
# Successfully installed comet_ml-3.58.6 configobj-5.0.9 dulwich-1.2.14 everett-3.1.0 python-box-6.1.0 wurlitzer-3.1.1
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (0.8.2)
# Collecting torchgeometry
#   Downloading torchgeometry-0.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from torchgeometry) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.0.0->torchgeometry) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.0.0->torchgeometry) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.0.0->torchgeometry) (3.0.3)
# Downloading torchgeometry-0.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: torchgeometry
# Successfully installed torchgeometry-0.1.2
# Collecting jpegio
#   Downloading jpegio-0.2.8.tar.gz (73.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 MB 10.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: jpegio
#   Building wheel for jpegio (pyproject.toml) ... done
#   Created wheel for jpegio: filename=jpegio-0.2.8-cp313-cp313-linux_x86_64.whl size=1342188 sha256=d1a48542d6ac0f791b7c813c7229f2c08ff96fa68158636eeba478841f4891aa
#   Stored in directory: /root/.cache/pip/wheels/9e/1e/5c/ba4a3749847e3fbd60d86215f96b3329573329c7b832a62f09
# Successfully built jpegio
# Installing collected packages: jpegio
# Successfully installed jpegio-0.2.8
# Collecting torch_dct
#   Downloading torch_dct-0.1.6-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.13/dist-packages (from torch_dct) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=0.4.1->torch_dct) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=0.4.1->torch_dct) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=0.4.1->torch_dct) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=0.4.1->torch_dct) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=0.4.1->torch_dct) (3.0.3)
# Downloading torch_dct-0.1.6-py3-none-any.whl (5.1 kB)
# Installing collected packages: torch_dct
# Successfully installed torch_dct-0.1.6
# Collecting kornia
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Collecting kornia-rs>=0.1.9 (from kornia)
#   Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from kornia) (26.3)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from kornia) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.0.0->kornia) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->kornia) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->kornia) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.0.0->kornia) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.0.0->kornia) (3.0.3)
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 68.5 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 92.5 MB/s eta 0:00:00
# Installing collected packages: kornia-rs, kornia
# Successfully installed kornia-0.8.3 kornia-rs-0.1.14

# %%
import torch
import torchvision
from pathlib import Path
from PIL import Image
import sys
import os
import shutil
from torchvision import transforms
import matplotlib.pyplot as plt

# dataloader
from torch.utils.data import Dataset, DataLoader, random_split

# jpeg
import torch_dct as dct
import numpy as np
import tempfile
import matplotlib.pyplot as plt
import kornia
import torch_dct

# to store-reload best model
from contextlib import redirect_stdout
import io
import json
import gc
from collections import OrderedDict

# for testing
import torch.nn.functional as F
from torchvision.utils import save_image

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Base path
BASE_DIR = "/content/drive/MyDrive/Colab Notebooks/tesi/" if 'google.colab' in str(get_ipython()) else "."
NAME = "02_add_degradation_steps"

# Directories
ZIP_PATH = os.path.join(BASE_DIR, "data", "img_align_celeba.zip")
LOCAL_DATA_ROOT = "/content/raw_data"
SRC_C_D = os.path.join(BASE_DIR, "src", "Cold-Diffusion-Models", "resolution-diffusion-pytorch", "resolution_diffusion_pytorch")
QUANT_TABLES = os.path.join(BASE_DIR, "assets/increase_steps20_qt.pt")

CHECKPOINT_DIR = os.path.join(BASE_DIR, "checkpoints", "coeff_quantized", "1_final_degradation_function", NAME)
OUTPUT_DIR = os.path.join(BASE_DIR, "outputs", "trainings", "coeff_quantized", "1_final_degradation_function", NAME)
TRAINED_MODEL_DIR = os.path.join(BASE_DIR, "trained_models", "cold_diffusion", "coeff_quantized", "1_final_degradation_function", NAME)

# importing the models
if SRC_C_D not in sys.path:
    sys.path.append(os.path.dirname(SRC_C_D))

# create folders
for path in [CHECKPOINT_DIR, OUTPUT_DIR, TRAINED_MODEL_DIR]:
    os.makedirs(path, exist_ok=True)

save_path = os.path.join(TRAINED_MODEL_DIR, f'{NAME}.pt')
quant_tables = torch.load(QUANT_TABLES)

# %%
if not os.path.exists(LOCAL_DATA_ROOT):
    print("Unzipping ...")
    # !unzip -q "{ZIP_PATH}" -d {LOCAL_DATA_ROOT}
    print("Done!")
else:
    print("Already unzipped")
# Out:
# Unzipping ...
# Done!

# %% [markdown]
# # Loading and PreProcessing

# %%
class CelebADataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.file_names = [f for f in os.listdir(root_dir) if f.endswith(('.jpg', '.jpeg'))]
        self.transform = transform

    def __len__(self):
        return len(self.file_names)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.file_names[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# Transform configuration
IMG_SIZE = 128
train_transform = transforms.Compose([
    transforms.CenterCrop(178),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x * 2) - 1)
])

batch_size_ = 8

# %%
# Loading dataset
dataset_path = os.path.join(LOCAL_DATA_ROOT, "img_align_celeba")
full_dataset = CelebADataset(root_dir=dataset_path, transform=train_transform)

# Split random
train_size = int(0.9 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size_, shuffle=True, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size_, shuffle=False, num_workers=2)

print(f"Dataset ready. Train: {len(train_dataset)} | Test: {len(test_dataset)}")
# Out:
# Dataset ready. Train: 182339 | Test: 20260

# %%
def sanity_check_dataloader(dataloader):
    try:
        batch = next(iter(dataloader))
    except Exception as e:
        print(f"Error in loading batch: {e}")
        return

    print(f"Batch Shape: {batch.shape}")
    print(f"Range: Min={batch.min():.2f}, Max={batch.max():.2f}")

    img_t = batch[0]

    # Denormalize from [-1, 1] to [0, 1] for visualization
    img_viz = (img_t + 1) / 2
    img_viz = img_viz.clamp(0, 1)

    # Convert to [H, W, C] for matplotlib
    img_np = img_viz.permute(1, 2, 0).numpy()

    plt.figure(figsize=(5, 5))
    plt.imshow(img_np)
    plt.axis('off')
    plt.show()

sanity_check_dataloader(train_loader)
# Out:
# Batch Shape: torch.Size([8, 3, 128, 128])
# Range: Min=-1.00, Max=1.00

# %% [markdown]
# # Configuration

# %%
IMG_SIZE = 128
batch_size_ = 16

# %% [markdown]
# ### Defining the new degradation function

# %% [markdown]
# Now I configure the model using the classes of the authors

# %%
# questo serve per eliminare conflitti col file celeb_128, dato che già chiama args
sys.argv = ['colab_kernel_launcher.py']

from resolution_diffusion_pytorch import Unet, GaussianDiffusion, Trainer

def find_last_checkpoint(save_folder):
    path = os.path.join(save_folder, f'model.pt')
    if os.path.exists(path):
        return path
    return None

# %%
from torch._prims_common import check
# --- CONFIGURATION ---
class Args:
    time_steps = 20
    train_steps = 5000
    save_folder = OUTPUT_DIR
    data_path = dataset_path
    checkpoint_path = CHECKPOINT_DIR
    load_path = find_last_checkpoint(checkpoint_path)
    train_routine = 'Final'
    resolution_routine = 'Incremental'
    sampling_routine = 'x0_step_down'
    image_size = IMG_SIZE
    channels = 3

args = Args()

# --- MODEL INITIALIZATION ---
model = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8),
    channels = args.channels
).cuda()

diffusion = GaussianDiffusion(
    model,
    image_size = args.image_size,
    device_of_kernel = 'cuda',
    channels = args.channels,
    timesteps = args.time_steps,
    loss_type = 'l1',
    resolution_routine = args.resolution_routine,
    train_routine = args.train_routine,
    sampling_routine = args.sampling_routine
).cuda()

# Support for multiple GPUs if available
if torch.cuda.device_count() > 1:
    diffusion = torch.nn.DataParallel(diffusion)

class DummyWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.module = model

    def forward(self, *args, **kwargs):
        return self.module(*args, **kwargs)

    def __getattr__(self, name):
        try:
            return super().__getattr__(name)
        except AttributeError:
            return getattr(self.module, name)

# Apply wrapper
if not isinstance(diffusion, torch.nn.DataParallel):
    diffusion = DummyWrapper(diffusion)
    print("DummyWrapper aggiornato")

trainer = Trainer(
    diffusion,
    dataset_path,
    image_size = args.image_size,
    train_batch_size = 16,
    train_lr = 0.0001,
    train_num_steps = args.train_steps,
    ema_decay = 0.995,
    fp16 = False,
    results_folder = args.save_folder,
    load_path = args.load_path,
    save_and_sample_every = 25,
    gradient_accumulate_every = 2
    )
trainer.checkpoint_path = Path(args.checkpoint_path)
# Out:
# Is Time embed used ?  True
# DummyWrapper aggiornato
# Loading :  /content/drive/MyDrive/Colab Notebooks/tesi/checkpoints/coeff_quantized/1_final_degradation_function/02_add_degradation_steps/model.pt

# %%
# State shared between consecutive steps - valid just as long as q_sample lasts
_dct_state = {
    'coeffs': None,     # real DCT coefficients (not quantized) - updated at each step
    'step': -1,         # last step applied
}

def get_quant_table_tensor(step, device):
    lum  = quant_tables[f'step{step}_luminance'].to(device)    # [8, 8]
    chrom = quant_tables[f'step{step}_chrominance'].to(device) # [8, 8]
    return lum, chrom

def img_to_dct_blocks(img_batch):
    """
    Pixel space [-1,1] -> DCT coefficients, frequency space.
    Returns (blocks_dct, bH, bW) where blocks_dct shape [B, C, bH*bW, 8, 8].
    """
    B, C, H, W = img_batch.shape
    x = (img_batch + 1) * 0.5                          # [-1,1] -> [0,1]
    x_ycbcr = kornia.color.rgb_to_ycbcr(x)             # [0,1] YCbCr
    x_255 = x_ycbcr * 255.0                            # [0,255]

    blocks = x_255.unfold(2, 8, 8).unfold(3, 8, 8)     # [B,C,bH,bW,8,8]
    bH, bW = blocks.shape[2], blocks.shape[3]
    blocks_flat = blocks.contiguous().reshape(B, C, bH * bW, 8, 8)
    dct_blocks = dct.dct_2d(blocks_flat, norm='ortho')  # [B,C,bH*bW,8,8]
    return dct_blocks, bH, bW

def dct_blocks_to_img(dct_blocks, bH, bW, B, C, H, W):
    """
    DCT coefficients → pixel space [-1,1].
    """
    result_flat = dct.idct_2d(dct_blocks, norm='ortho')
    result = result_flat.reshape(B, C, bH, bW, 8, 8)
    result = result.permute(0, 1, 2, 4, 3, 5).contiguous().reshape(B, C, H, W)
    result_01 = (result / 255.0).clamp(0, 1)
    result_rgb = kornia.color.ycbcr_to_rgb(result_01)
    return (result_rgb * 2 - 1).clamp(-1, 1)

def quantize_dct(dct_blocks, q_lum, q_chrom):
    """
    Quantizes DCT coefficients with luma/chroma tables.
    Returns quantized coefficients, not divided by q yet.
    """
    q_lum   = q_lum.unsqueeze(0).unsqueeze(0)    # [1,1,8,8]
    q_chrom = q_chrom.unsqueeze(0).unsqueeze(0)  # [1,1,8,8]
    out = dct_blocks.clone()
    out[:, 0:1] = torch.round(dct_blocks[:, 0:1] / q_lum)   * q_lum
    # out[:, 1:3] = torch.round(dct_blocks[:, 1:3] / q_chrom) * q_chrom
    return out

def dequantize_dct(dct_blocks, q_lum, q_chrom):
    """
    Dequantizes DCT coefficients with luma/chroma tables.
    Thanks to the saved original coefficients,
    and since the current coefficients are already real,
    this funtion does nothing.
    """
    return dct_blocks

def jpeg_degradation(img_batch, step):
    """
    Cumulative JPEG degradation in frequence space

    - step = 0: no degradation, resets state
    - step = 1: DCT from zero on original image -> quantize with table [1]
    - step > 1: quantizes with table [t] -> update state
    """
    current_step = step.item() if torch.is_tensor(step) else step

    if current_step == 0:
        # Reset state, no degradation
        _dct_state['coeffs'] = None
        _dct_state['step'] = -1
        return img_batch

    device = img_batch.device
    B, C, H, W = img_batch.shape

    if current_step == 1 or _dct_state['coeffs'] is None:
        # The first step compute DCT coefficients
        dct_blocks, bH, bW = img_to_dct_blocks(img_batch)
        _dct_state['original_dct'] = dct_blocks.clone()  # save original
        _dct_state['bH'] = bH
        _dct_state['bW'] = bW
    else:
        # Other steps: always starts from x0 for applying the new table
        dct_blocks = _dct_state['original_dct'].to(device)
        bH = _dct_state['bH']
        bW = _dct_state['bW']

    # Apply current step table directly on original coefficients
    q_lum, q_chrom = get_quant_table_tensor(current_step, device)
    quantized = quantize_dct(dct_blocks, q_lum, q_chrom)

    # Update the state
    _dct_state['coeffs'] = quantized
    _dct_state['step'] = current_step

    return dct_blocks_to_img(quantized, bH, bW, B, C, H, W)

# %%
# --- OVERWRITING ---
inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion
inner_model.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]

# %% [markdown]
# ### Testing the new function

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
fig, axs = plt.subplots(1, 10, figsize=(20, 3))

img_path = '/content/raw_data/img_align_celeba/000002.jpg'

# Load the image and apply transformations
x_test_pil = Image.open(img_path).convert('RGB')
x_test_tensor = train_transform(x_test_pil).unsqueeze(0).to(device)

for step in range(10):
    t = torch.tensor([step], device=device)
    x_deg = jpeg_degradation(x_test_tensor, t)
    img_vis = ((x_deg.squeeze().permute(1,2,0) + 1) * 0.5).cpu().numpy()
    axs[step].imshow(img_vis.clip(0,1))
    axs[step].set_title(f"s={step}", fontsize=8)
    axs[step].axis('off')
plt.tight_layout()
plt.show()

# %%
def show_degradation(img_path, steps_to_show):
    x_0_pil = Image.open(img_path)

    x_0_processed = train_transform(x_0_pil)
    x_0 = x_0_processed.unsqueeze(0).to('cuda')

    n_steps = len(steps_to_show)

    inner_model = diffusion

    # --- DEGRADATION ---
    print("Degradation (DCT)...")
    fig, axs = plt.subplots(1, n_steps, figsize=(15, 5))
    print(f"Range image: [{x_0.min()}, {x_0.max()}]")
    for i, t in enumerate(steps_to_show):
        with torch.no_grad():
            x_t = inner_model.q_sample(x_0, torch.tensor([t], device='cuda'))

        # From [-1, 1] to [0, 1] for visualization
        img_vis = ((x_t.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy()
        axs[i].imshow(img_vis.clip(0, 1))
        axs[i].set_title(f"Step t={t}")
        axs[i].axis('off')
    plt.show()


img_path = '/content/raw_data/img_align_celeba/000002.jpg'
steps_to_show = [i for i in range(args.time_steps)]
show_degradation(img_path, steps_to_show)
# Out:
# Degradation (DCT)...
# Range image: [-1.0, 1.0]

# %% [markdown]
# # Training
# ### helper functions

# %%
# psnr loss computation
def calculate_psnr(img1, img2):
    # from [-1, 1] to [0, 1] for PSNR computation
    img1 = (img1.detach() + 1.0) / 2.0
    img2 = (img2.detach() + 1.0) / 2.0
    mse = torch.mean((img1 - img2) ** 2)
    if mse == 0: return 100.0
    return (20 * torch.log10(1.0 / torch.sqrt(mse))).item()

# to reset the weights after each training
def weight_reset(m):
    """
    Goes through each layer of the model and resets the weights.
    """
    if isinstance(m, torch.nn.Conv2d) or isinstance(m, torch.nn.Linear):
        m.reset_parameters()
    if isinstance(m, torch.nn.BatchNorm2d):
        m.reset_parameters()

# %% [markdown]
# ### sanity check
# Making sure that the degradation function is the one I defined:

# %%
models_to_patch = [diffusion, trainer.model, trainer.ema_model]

for model in models_to_patch:
    m = model.module if hasattr(model, 'module') else model
    m.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]
    print(f"Patched {type(m).__name__} — id: {id(m)} — func[0]: {m.func[0]}")
# Out:
# Patched GaussianDiffusion — id: 139752540084208 — func[0]: <function <lambda> at 0x7f1aa01f5440>
# Patched GaussianDiffusion — id: 139752540084208 — func[0]: <function <lambda> at 0x7f1aa0146ca0>
# Patched GaussianDiffusion — id: 139752540147216 — func[0]: <function <lambda> at 0x7f1aa01f5440>

# %%
# Testing q_sample on trainer.model
x_test = next(iter(trainer.dl)).cuda()[:1]
t_test = torch.tensor([5]).cuda()

m = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model
x_deg = m.q_sample(x_test, t_test)
diff = (x_test - x_deg).abs().mean().item()
print(f"Differenza step 5 su trainer.model: {diff:.4f}")  # deve essere > 0

m_ema = trainer.ema_model.module if hasattr(trainer.ema_model, 'module') else trainer.ema_model
x_deg_ema = m_ema.q_sample(x_test, t_test)
diff_ema = (x_test - x_deg_ema).abs().mean().item()
print(f"Differenza step 5 su trainer.ema_model: {diff_ema:.4f}")  # deve essere > 0
# Out:
# Differenza step 5 su trainer.model: 0.0536
# Differenza step 5 su trainer.ema_model: 0.0536

# %% [markdown]
# ### checkpoints
# Overwriting the save and load functions so that I save also the optimizer's state and the losses:

# %%
def patched_save(self):
    data = {
        'step': self.step,
        'model': self.model.state_dict(),
        'ema': self.ema_model.state_dict(),
        'optimizer': self.opt.state_dict(),  # added
        'losses': losses  # added
    }

    # Convert checkpoint_path to Path object for proper path joining
    checkpoint_path_obj = Path(self.checkpoint_path)

    torch.save(data, str(checkpoint_path_obj / 'model.pt'))
    print(f"Saved checkpoint at step {self.step}")

def patched_load(self, load_path):
    print("Loading: ", load_path)
    data = torch.load(load_path)
    self.step = data['step']
    self.model.load_state_dict(data['model'])
    self.ema_model.load_state_dict(data['ema'])
    if 'optimizer' in data:
        self.opt.load_state_dict(data['optimizer'])
        print(f"Optimizer Loaded")
    if 'losses' in data:
        losses.extend(data['losses'])
        print(f"Loaded {len(losses)} previous losses")

# Rewriting modules
trainer.save = patched_save.__get__(trainer, type(trainer))
trainer.load = patched_load.__get__(trainer, type(trainer))

# %% [markdown]
# Looking for checkpoints:

# %%
# Look for checkpoint
args.load_path = find_last_checkpoint(trainer.checkpoint_path)
print(f"Found checkpoint: {args.load_path}")
# Out:
# Found checkpoint: /content/drive/MyDrive/Colab Notebooks/tesi/checkpoints/coeff_quantized/1_final_degradation_function/02_add_degradation_steps/model.pt

# %% [markdown]
# ### Training

# %%
if TRAIN:
    losses = []
    temp_losses = []
    acc_step = trainer.gradient_accumulate_every
    # inner_model.apply(weight_reset)

    if isinstance(args, tuple):
        total_steps = args[0].train_steps
    else:
        total_steps = args.train_steps

    inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion

    # restoration
    if hasattr(inner_model, '_original_forward'):
        inner_model.forward = inner_model._original_forward
    else:
        inner_model._original_forward = inner_model.forward

    def forward_wrapper(*args_func, **kwargs_func):
        loss = inner_model._original_forward(*args_func, **kwargs_func)
        temp_losses.append(loss.item())

        if len(temp_losses) == acc_step:
            avg_loss = sum(temp_losses) / len(temp_losses)
            losses.append(avg_loss)
            temp_losses.clear()

        return loss

    inner_model.forward = forwajperd_wrapper

    # Looking for checkpoints
    if args.load_path is not None and os.path.exists(args.load_path):
        trainer.load(args.load_path)
        print(f"Resumed from step {trainer.step}")
    else:
        print("Training from scratch")

    print(f"Training for {total_steps} steps")
    trainer.train()
    print("\n Training complete!")
# Out:
# Skipping training

# %% [markdown]
# ### Learning curve

# %%
if TRAIN:
    if len(losses) > 0:
        plt.figure(figsize=(10, 5))
        plt.plot(losses, label='Train Loss', color='#3498db', alpha=0.5)

        plt.title('Loss Curve')
        plt.xlabel('Step')
        plt.ylabel('Loss')
        plt.grid(True, alpha=.3)
        plt.legend()

        # saving the learning curve
        os.makedirs(args.save_folder, exist_ok=True)
        plt.savefig(f"{args.save_folder}/learning_curve.png")
        plt.show()
    else:
        print("No loss found, problems in training")

else:
    print("Skipping training, looking for saved learning curve.")
    learning_curve_path = f"{args.save_folder}/learning_curve.png"
    if os.path.exists(learning_curve_path):
        try:
            img = Image.open(learning_curve_path)
            plt.figure(figsize=(10, 5))
            plt.imshow(img)
            plt.title('Saved Loss Curve')
            plt.axis('off') # Hide axes for image
            plt.show()
        except Exception as e:
            print(f"Error loading or displaying saved learning curve: {e}")
    else:
        print(f"No saved learning curve found at {learning_curve_path}")
# Out:
# Skipping training, looking for saved learning curve.

# %% [markdown]
# ### Save model

# %%
if TRAIN:
    # saving the weights
    torch.save(diffusion.state_dict(), save_path)

    print(f"Model saved")

# %% [markdown]
# ### Reload model

# %%
if not TRAIN:
    trained_model = torch.load(save_path)

    new_state_dict = OrderedDict()
    for k, v in trained_model.items():
        new_key = k.replace('module.', '', 1)
        new_state_dict[new_key] = v

    inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion
    inner_model.load_state_dict(new_state_dict)

    inner_model.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]

    diffusion.eval()
    print("Model loaded")
# Out:
# Model loaded

# %%
if not TRAIN:
    models_to_patch = [diffusion, trainer.model, trainer.ema_model]

    for model in models_to_patch:
        m = model.module if hasattr(model, 'module') else model
        m.func = [lambda img, s=i: jpeg_degradation(img, s) for i in range(args.time_steps)]
        print(f"Patched {type(m).__name__} — id: {id(m)} — func[0]: {m.func[0]}")
# Out:
# Patched GaussianDiffusion — id: 139752540084208 — func[0]: <function <lambda> at 0x7f1aac81c4a0>
# Patched GaussianDiffusion — id: 139752540084208 — func[0]: <function <lambda> at 0x7f1a89f27920>
# Patched GaussianDiffusion — id: 139752540147216 — func[0]: <function <lambda> at 0x7f1aac81c4a0>

# %% [markdown]
# ## Visualization
#
# Performing the degradation and reconstruction on an image

# %%
# --- PREPARATION ---
inner_model = diffusion

x_0_pil = Image.open(img_path)     # taking first image of the batch

# Apply the same preprocessing as for training data
preprocess = transforms.Compose([
    transforms.CenterCrop(178),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
])
to_tensor = transforms.ToTensor()

x_0_processed = preprocess(x_0_pil)
x_0 = (to_tensor(x_0_processed) * 2) - 1 # Convert to tensor and normalize to [-1, 1]
x_0 = x_0.unsqueeze(0).to('cuda') # Add batch dimension and move to GPU

# visualization parameters
steps_to_show = [0, 3, 6, 9]
n_steps = len(steps_to_show)

# --- DEGRADATION ---
print("Degradation (DCT)...")
fig, axs = plt.subplots(1, n_steps, figsize=(15, 5))
for i, t in enumerate(steps_to_show):
    with torch.no_grad():
        x_t = inner_model.q_sample(x_0, torch.tensor([t], device='cuda'))

    # From [-1, 1] to [0, 1]
    print(f"Range of Image before plotting: {x_t.min()}, {x_t.max()}")
    img_vis = ((x_t.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy()
    axs[i].imshow(img_vis.clip(0, 1))
    axs[i].set_title(f"Degradation Step t={t}")
    axs[i].axis('off')
plt.show()


# --- RECONSTRUCTION ---
print("Reconstruction ...")

with torch.no_grad():
    xt, direct_recons,_img = inner_model.sample(batch_size=1, img=x_t)

    print(f"Range of Image reconstructed before plotting: {_img.min()}, {_img.max()}")
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Original Image
axs[0].imshow(((x_0.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[0].set_title("Original (x0)")

# Maximum degradation
axs[1].imshow(((xt.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[1].set_title("Degraded (t=9)")

# Reconstruction
axs[2].imshow(((_img.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[2].set_title("Reconstructed")

for ax in axs: ax.axis('off')
plt.show()

psnr = calculate_psnr(x_0,_img)
print(f"PSNR: {psnr}")

l1_loss = F.l1_loss(_img, x_0).item()
print(f"L1 Loss: {l1_loss}")
# Out:
# Degradation (DCT)...
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 1.0
# Reconstruction ...
# Range of Image reconstructed before plotting: -2.007704257965088, 2.324106216430664
# PSNR: 17.643470764160156
# L1 Loss: 0.2044645994901657

# %% [markdown]
# # Test

# %%
if TEST:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results_psnr = []
    best_results = []
    worst_results = []

    max_test_images = 1000
    processed_images = 0

    print(f"Starting testing on max {max_test_images} images...")

    diffusion.eval()

    with torch.no_grad():
        for batch in test_loader:
            if processed_images >= max_test_images:
                print("dropping last batch")
                break

            gt_tensor_norm = batch.to(device)
            curr_batch_size = min(gt_tensor_norm.shape[0], max_test_images - processed_images)
            gt_tensor_norm = gt_tensor_norm[:curr_batch_size]

            _, _, restored_norm = diffusion.sample(batch_size=curr_batch_size, img=gt_tensor_norm)

            gt_01 = (gt_tensor_norm + 1).mul_(0.5)
            restored_01 = (restored_norm + 1).mul_(0.5).clamp_(0, 1)

            gt_cpu = gt_01.cpu()
            restored_cpu = restored_01.cpu()

            del gt_tensor_norm, restored_norm, gt_01, restored_01
            torch.cuda.empty_cache()

            for b in range(curr_batch_size):
                single_gt = gt_cpu[b:b+1]
                single_restored = restored_cpu[b:b+1]

                psnr = calculate_psnr(single_gt, single_restored)
                results_psnr.append(psnr)

                current_res = {
                    'psnr': psnr,
                    'index': processed_images,
                    'restored': single_restored,
                    'gt': single_gt
                }

                # Best 5
                if len(best_results) < 5 or psnr > best_results[-1]['psnr']:
                    best_results.append(current_res)
                    best_results.sort(key=lambda x: x['psnr'], reverse=True)
                    best_results = best_results[:5]

                # Worst 5
                if len(worst_results) < 5 or psnr < worst_results[-1]['psnr']:
                    worst_results.append(current_res)
                    worst_results.sort(key=lambda x: x['psnr'])
                    worst_results = worst_results[:5]

                processed_images += 1
                print(f"Processing {processed_images}/{max_test_images} - PSNR: {psnr:.2f} dB")

            del gt_cpu, restored_cpu
            gc.collect()

    avg_psnr = sum(results_psnr) / len(results_psnr)
    print(f"\nTest completed")
    print(f"Mean PSNR over {processed_images} images: {avg_psnr:.2f} dB")
else:
    print("Skipping testing")
# Out:
# Starting testing on max 1000 images...
# Processing 1/1000 - PSNR: 28.33 dB
# Processing 2/1000 - PSNR: 27.50 dB
# Processing 3/1000 - PSNR: 28.32 dB
# Processing 4/1000 - PSNR: 26.71 dB
# Processing 5/1000 - PSNR: 26.56 dB
# Processing 6/1000 - PSNR: 28.27 dB
# Processing 7/1000 - PSNR: 26.92 dB
# Processing 8/1000 - PSNR: 28.29 dB
# Processing 9/1000 - PSNR: 26.84 dB
# Processing 10/1000 - PSNR: 25.81 dB
# Processing 11/1000 - PSNR: 26.41 dB
# Processing 12/1000 - PSNR: 25.04 dB
# Processing 13/1000 - PSNR: 26.16 dB
# Processing 14/1000 - PSNR: 24.84 dB
# Processing 15/1000 - PSNR: 24.84 dB
# Processing 16/1000 - PSNR: 27.39 dB
# Processing 17/1000 - PSNR: 26.46 dB
# Processing 18/1000 - PSNR: 24.00 dB
# Processing 19/1000 - PSNR: 28.28 dB
# Processing 20/1000 - PSNR: 26.79 dB
# Processing 21/1000 - PSNR: 24.99 dB
# Processing 22/1000 - PSNR: 28.26 dB
# Processing 23/1000 - PSNR: 25.70 dB
# Processing 24/1000 - PSNR: 25.32 dB
# Processing 25/1000 - PSNR: 23.75 dB
# Processing 26/1000 - PSNR: 23.52 dB
# Processing 27/1000 - PSNR: 25.11 dB
# Processing 28/1000 - PSNR: 27.01 dB
# Processing 29/1000 - PSNR: 25.40 dB
# Processing 30/1000 - PSNR: 25.34 dB
# Processing 31/1000 - PSNR: 25.99 dB
# Processing 32/1000 - PSNR: 25.92 dB
# Processing 33/1000 - PSNR: 25.44 dB
# Processing 34/1000 - PSNR: 26.69 dB
# Processing 35/1000 - PSNR: 26.93 dB
# Processing 36/1000 - PSNR: 24.75 dB
# Processing 37/1000 - PSNR: 26.94 dB
# Processing 38/1000 - PSNR: 26.49 dB
# Processing 39/1000 - PSNR: 27.75 dB
# Processing 40/1000 - PSNR: 27.89 dB
# Processing 41/1000 - PSNR: 23.51 dB
# Processing 42/1000 - PSNR: 26.20 dB
# Processing 43/1000 - PSNR: 28.50 dB
# Processing 44/1000 - PSNR: 26.73 dB
# Processing 45/1000 - PSNR: 28.21 dB
# Processing 46/1000 - PSNR: 24.47 dB
# Processing 47/1000 - PSNR: 25.86 dB
# Processing 48/1000 - PSNR: 22.74 dB
# Processing 49/1000 - PSNR: 25.14 dB
# Processing 50/1000 - PSNR: 27.16 dB
# Processing 51/1000 - PSNR: 26.93 dB
# Processing 52/1000 - PSNR: 27.41 dB
# Processing 53/1000 - PSNR: 27.51 dB
# Processing 54/1000 - PSNR: 26.01 dB
# Processing 55/1000 - PSNR: 27.15 dB
# Processing 56/1000 - PSNR: 27.99 dB
# Processing 57/1000 - PSNR: 27.56 dB
# Processing 58/1000 - PSNR: 24.82 dB
# Processing 59/1000 - PSNR: 28.53 dB
# Processing 60/1000 - PSNR: 26.96 dB
# Processing 61/1000 - PSNR: 25.59 dB
# Processing 62/1000 - PSNR: 25.71 dB
# Processing 63/1000 - PSNR: 26.95 dB
# Processing 64/1000 - PSNR: 26.18 dB
# Processing 65/1000 - PSNR: 25.90 dB
# Processing 66/1000 - PSNR: 27.58 dB
# Processing 67/1000 - PSNR: 26.47 dB
# Processing 68/1000 - PSNR: 26.69 dB
# Processing 69/1000 - PSNR: 24.35 dB
# Processing 70/1000 - PSNR: 22.69 dB
# Processing 71/1000 - PSNR: 25.93 dB
# Processing 72/1000 - PSNR: 27.64 dB
# Processing 73/1000 - PSNR: 26.89 dB
# Processing 74/1000 - PSNR: 27.66 dB
# Processing 75/1000 - PSNR: 25.91 dB
# Processing 76/1000 - PSNR: 25.33 dB
# Processing 77/1000 - PSNR: 28.18 dB
# Processing 78/1000 - PSNR: 25.21 dB
# Processing 79/1000 - PSNR: 27.18 dB
# Processing 80/1000 - PSNR: 25.27 dB
# Processing 81/1000 - PSNR: 26.70 dB
# Processing 82/1000 - PSNR: 25.38 dB
# Processing 83/1000 - PSNR: 24.72 dB
# Processing 84/1000 - PSNR: 28.33 dB
# Processing 85/1000 - PSNR: 26.28 dB
# Processing 86/1000 - PSNR: 25.39 dB
# Processing 87/1000 - PSNR: 26.62 dB
# Processing 88/1000 - PSNR: 26.37 dB
# Processing 89/1000 - PSNR: 23.83 dB
# Processing 90/1000 - PSNR: 24.84 dB
# Processing 91/1000 - PSNR: 28.33 dB
# Processing 92/1000 - PSNR: 27.01 dB
# Processing 93/1000 - PSNR: 24.98 dB
# Processing 94/1000 - PSNR: 26.33 dB
# Processing 95/1000 - PSNR: 25.49 dB
# Processing 96/1000 - PSNR: 26.49 dB
# Processing 97/1000 - PSNR: 26.07 dB
# Processing 98/1000 - PSNR: 27.50 dB
# Processing 99/1000 - PSNR: 26.44 dB
# Processing 100/1000 - PSNR: 26.69 dB
# Processing 101/1000 - PSNR: 25.89 dB
# Processing 102/1000 - PSNR: 26.24 dB
# Processing 103/1000 - PSNR: 23.83 dB
# Processing 104/1000 - PSNR: 26.46 dB
# Processing 105/1000 - PSNR: 25.62 dB
# Processing 106/1000 - PSNR: 27.09 dB
# Processing 107/1000 - PSNR: 25.86 dB
# Processing 108/1000 - PSNR: 25.84 dB
# Processing 109/1000 - PSNR: 28.50 dB
# Processing 110/1000 - PSNR: 24.58 dB
# Processing 111/1000 - PSNR: 28.07 dB
# Processing 112/1000 - PSNR: 26.17 dB
# Processing 113/1000 - PSNR: 26.29 dB
# Processing 114/1000 - PSNR: 26.08 dB
# Processing 115/1000 - PSNR: 26.82 dB
# Processing 116/1000 - PSNR: 27.11 dB
# Processing 117/1000 - PSNR: 25.74 dB
# Processing 118/1000 - PSNR: 26.85 dB
# Processing 119/1000 - PSNR: 25.61 dB
# Processing 120/1000 - PSNR: 26.68 dB
# Processing 121/1000 - PSNR: 27.33 dB
# Processing 122/1000 - PSNR: 27.22 dB
# Processing 123/1000 - PSNR: 26.05 dB
# Processing 124/1000 - PSNR: 24.69 dB
# Processing 125/1000 - PSNR: 25.30 dB
# Processing 126/1000 - PSNR: 26.83 dB
# Processing 127/1000 - PSNR: 26.58 dB
# Processing 128/1000 - PSNR: 26.13 dB
# Processing 129/1000 - PSNR: 27.08 dB
# Processing 130/1000 - PSNR: 25.50 dB
# Processing 131/1000 - PSNR: 27.79 dB
# Processing 132/1000 - PSNR: 25.29 dB
# Processing 133/1000 - PSNR: 27.35 dB
# Processing 134/1000 - PSNR: 27.64 dB
# Processing 135/1000 - PSNR: 26.58 dB
# Processing 136/1000 - PSNR: 24.75 dB
# Processing 137/1000 - PSNR: 26.11 dB
# Processing 138/1000 - PSNR: 26.12 dB
# Processing 139/1000 - PSNR: 24.23 dB
# Processing 140/1000 - PSNR: 26.47 dB
# Processing 141/1000 - PSNR: 25.88 dB
# Processing 142/1000 - PSNR: 27.47 dB
# Processing 143/1000 - PSNR: 26.09 dB
# Processing 144/1000 - PSNR: 27.52 dB
# Processing 145/1000 - PSNR: 25.94 dB
# Processing 146/1000 - PSNR: 27.01 dB
# Processing 147/1000 - PSNR: 28.24 dB
# Processing 148/1000 - PSNR: 29.02 dB
# Processing 149/1000 - PSNR: 27.78 dB
# Processing 150/1000 - PSNR: 27.45 dB
# Processing 151/1000 - PSNR: 24.98 dB
# Processing 152/1000 - PSNR: 27.84 dB
# Processing 153/1000 - PSNR: 25.51 dB
# Processing 154/1000 - PSNR: 28.73 dB
# Processing 155/1000 - PSNR: 26.78 dB
# Processing 156/1000 - PSNR: 26.85 dB
# Processing 157/1000 - PSNR: 26.84 dB
# Processing 158/1000 - PSNR: 27.28 dB
# Processing 159/1000 - PSNR: 27.22 dB
# Processing 160/1000 - PSNR: 26.34 dB
# Processing 161/1000 - PSNR: 26.54 dB
# Processing 162/1000 - PSNR: 25.24 dB
# Processing 163/1000 - PSNR: 28.01 dB
# Processing 164/1000 - PSNR: 25.56 dB
# Processing 165/1000 - PSNR: 24.71 dB
# Processing 166/1000 - PSNR: 24.87 dB
# Processing 167/1000 - PSNR: 26.10 dB
# Processing 168/1000 - PSNR: 25.78 dB
# Processing 169/1000 - PSNR: 26.59 dB
# Processing 170/1000 - PSNR: 25.48 dB
# Processing 171/1000 - PSNR: 26.75 dB
# Processing 172/1000 - PSNR: 25.99 dB
# Processing 173/1000 - PSNR: 27.96 dB
# Processing 174/1000 - PSNR: 26.54 dB
# Processing 175/1000 - PSNR: 27.58 dB
# Processing 176/1000 - PSNR: 25.24 dB
# Processing 177/1000 - PSNR: 28.34 dB
# Processing 178/1000 - PSNR: 27.49 dB
# Processing 179/1000 - PSNR: 25.93 dB
# Processing 180/1000 - PSNR: 26.62 dB
# Processing 181/1000 - PSNR: 28.20 dB
# Processing 182/1000 - PSNR: 26.36 dB
# Processing 183/1000 - PSNR: 26.72 dB
# Processing 184/1000 - PSNR: 27.25 dB
# Processing 185/1000 - PSNR: 27.13 dB
# Processing 186/1000 - PSNR: 27.24 dB
# Processing 187/1000 - PSNR: 28.84 dB
# Processing 188/1000 - PSNR: 28.34 dB
# Processing 189/1000 - PSNR: 28.51 dB
# Processing 190/1000 - PSNR: 26.71 dB
# Processing 191/1000 - PSNR: 26.95 dB
# Processing 192/1000 - PSNR: 30.47 dB
# Processing 193/1000 - PSNR: 23.30 dB
# Processing 194/1000 - PSNR: 24.49 dB
# Processing 195/1000 - PSNR: 26.02 dB
# Processing 196/1000 - PSNR: 26.05 dB
# Processing 197/1000 - PSNR: 28.44 dB
# Processing 198/1000 - PSNR: 26.96 dB
# Processing 199/1000 - PSNR: 27.26 dB
# Processing 200/1000 - PSNR: 26.77 dB
# Processing 201/1000 - PSNR: 29.49 dB
# Processing 202/1000 - PSNR: 23.50 dB
# Processing 203/1000 - PSNR: 23.54 dB
# Processing 204/1000 - PSNR: 25.63 dB
# Processing 205/1000 - PSNR: 26.12 dB
# Processing 206/1000 - PSNR: 25.49 dB
# Processing 207/1000 - PSNR: 27.16 dB
# Processing 208/1000 - PSNR: 24.90 dB
# Processing 209/1000 - PSNR: 25.35 dB
# Processing 210/1000 - PSNR: 24.34 dB
# Processing 211/1000 - PSNR: 26.54 dB
# Processing 212/1000 - PSNR: 24.79 dB
# Processing 213/1000 - PSNR: 26.78 dB
# Processing 214/1000 - PSNR: 25.88 dB
# Processing 215/1000 - PSNR: 26.18 dB
# Processing 216/1000 - PSNR: 28.37 dB
# Processing 217/1000 - PSNR: 25.63 dB
# Processing 218/1000 - PSNR: 26.50 dB
# Processing 219/1000 - PSNR: 26.64 dB
# Processing 220/1000 - PSNR: 26.28 dB
# Processing 221/1000 - PSNR: 23.23 dB
# Processing 222/1000 - PSNR: 25.55 dB
# Processing 223/1000 - PSNR: 25.52 dB
# Processing 224/1000 - PSNR: 27.17 dB
# Processing 225/1000 - PSNR: 28.12 dB
# Processing 226/1000 - PSNR: 28.14 dB
# Processing 227/1000 - PSNR: 27.64 dB
# Processing 228/1000 - PSNR: 26.13 dB
# Processing 229/1000 - PSNR: 25.79 dB
# Processing 230/1000 - PSNR: 26.37 dB
# Processing 231/1000 - PSNR: 25.31 dB
# Processing 232/1000 - PSNR: 23.61 dB
# Processing 233/1000 - PSNR: 28.65 dB
# Processing 234/1000 - PSNR: 29.10 dB
# Processing 235/1000 - PSNR: 27.26 dB
# Processing 236/1000 - PSNR: 24.72 dB
# Processing 237/1000 - PSNR: 24.54 dB
# Processing 238/1000 - PSNR: 26.28 dB
# Processing 239/1000 - PSNR: 28.59 dB
# Processing 240/1000 - PSNR: 24.01 dB
# Processing 241/1000 - PSNR: 25.48 dB
# Processing 242/1000 - PSNR: 25.84 dB
# Processing 243/1000 - PSNR: 27.86 dB
# Processing 244/1000 - PSNR: 25.50 dB
# Processing 245/1000 - PSNR: 24.60 dB
# Processing 246/1000 - PSNR: 26.35 dB
# Processing 247/1000 - PSNR: 25.20 dB
# Processing 248/1000 - PSNR: 26.93 dB
# Processing 249/1000 - PSNR: 25.95 dB
# Processing 250/1000 - PSNR: 26.02 dB
# Processing 251/1000 - PSNR: 28.28 dB
# Processing 252/1000 - PSNR: 25.02 dB
# Processing 253/1000 - PSNR: 25.43 dB
# Processing 254/1000 - PSNR: 25.54 dB
# Processing 255/1000 - PSNR: 25.85 dB
# Processing 256/1000 - PSNR: 24.07 dB
# Processing 257/1000 - PSNR: 28.48 dB
# Processing 258/1000 - PSNR: 26.39 dB
# Processing 259/1000 - PSNR: 23.71 dB
# Processing 260/1000 - PSNR: 23.85 dB
# Processing 261/1000 - PSNR: 25.21 dB
# Processing 262/1000 - PSNR: 26.11 dB
# Processing 263/1000 - PSNR: 23.87 dB
# Processing 264/1000 - PSNR: 24.27 dB
# Processing 265/1000 - PSNR: 27.35 dB
# Processing 266/1000 - PSNR: 26.01 dB
# Processing 267/1000 - PSNR: 26.83 dB
# Processing 268/1000 - PSNR: 27.21 dB
# Processing 269/1000 - PSNR: 26.49 dB
# Processing 270/1000 - PSNR: 23.00 dB
# Processing 271/1000 - PSNR: 24.25 dB
# Processing 272/1000 - PSNR: 25.78 dB
# Processing 273/1000 - PSNR: 27.14 dB
# Processing 274/1000 - PSNR: 28.78 dB
# Processing 275/1000 - PSNR: 26.71 dB
# Processing 276/1000 - PSNR: 26.94 dB
# Processing 277/1000 - PSNR: 27.30 dB
# Processing 278/1000 - PSNR: 28.38 dB
# Processing 279/1000 - PSNR: 24.22 dB
# Processing 280/1000 - PSNR: 26.42 dB
# Processing 281/1000 - PSNR: 27.02 dB
# Processing 282/1000 - PSNR: 22.90 dB
# Processing 283/1000 - PSNR: 25.96 dB
# Processing 284/1000 - PSNR: 25.41 dB
# Processing 285/1000 - PSNR: 26.80 dB
# Processing 286/1000 - PSNR: 27.02 dB
# Processing 287/1000 - PSNR: 24.81 dB
# Processing 288/1000 - PSNR: 27.49 dB
# Processing 289/1000 - PSNR: 26.99 dB
# Processing 290/1000 - PSNR: 26.73 dB
# Processing 291/1000 - PSNR: 25.01 dB
# Processing 292/1000 - PSNR: 26.15 dB
# Processing 293/1000 - PSNR: 25.33 dB
# Processing 294/1000 - PSNR: 27.88 dB
# Processing 295/1000 - PSNR: 26.76 dB
# Processing 296/1000 - PSNR: 26.29 dB
# Processing 297/1000 - PSNR: 28.92 dB
# Processing 298/1000 - PSNR: 25.44 dB
# Processing 299/1000 - PSNR: 24.08 dB
# Processing 300/1000 - PSNR: 25.11 dB
# Processing 301/1000 - PSNR: 26.00 dB
# Processing 302/1000 - PSNR: 26.14 dB
# Processing 303/1000 - PSNR: 26.21 dB
# Processing 304/1000 - PSNR: 30.13 dB
# Processing 305/1000 - PSNR: 28.42 dB
# Processing 306/1000 - PSNR: 28.81 dB
# Processing 307/1000 - PSNR: 29.45 dB
# Processing 308/1000 - PSNR: 25.75 dB
# Processing 309/1000 - PSNR: 27.55 dB
# Processing 310/1000 - PSNR: 26.93 dB
# Processing 311/1000 - PSNR: 25.92 dB
# Processing 312/1000 - PSNR: 26.74 dB
# Processing 313/1000 - PSNR: 25.40 dB
# Processing 314/1000 - PSNR: 25.75 dB
# Processing 315/1000 - PSNR: 26.27 dB
# Processing 316/1000 - PSNR: 26.81 dB
# Processing 317/1000 - PSNR: 25.49 dB
# Processing 318/1000 - PSNR: 28.13 dB
# Processing 319/1000 - PSNR: 28.25 dB
# Processing 320/1000 - PSNR: 24.77 dB
# Processing 321/1000 - PSNR: 27.49 dB
# Processing 322/1000 - PSNR: 26.69 dB
# Processing 323/1000 - PSNR: 25.21 dB
# Processing 324/1000 - PSNR: 24.05 dB
# Processing 325/1000 - PSNR: 26.59 dB
# Processing 326/1000 - PSNR: 26.33 dB
# Processing 327/1000 - PSNR: 27.02 dB
# Processing 328/1000 - PSNR: 29.71 dB
# Processing 329/1000 - PSNR: 28.35 dB
# Processing 330/1000 - PSNR: 28.96 dB
# Processing 331/1000 - PSNR: 28.11 dB
# Processing 332/1000 - PSNR: 27.37 dB
# Processing 333/1000 - PSNR: 25.04 dB
# Processing 334/1000 - PSNR: 25.82 dB
# Processing 335/1000 - PSNR: 27.15 dB
# Processing 336/1000 - PSNR: 25.05 dB
# Processing 337/1000 - PSNR: 25.76 dB
# Processing 338/1000 - PSNR: 25.41 dB
# Processing 339/1000 - PSNR: 24.12 dB
# Processing 340/1000 - PSNR: 26.45 dB
# Processing 341/1000 - PSNR: 26.80 dB
# Processing 342/1000 - PSNR: 25.05 dB
# Processing 343/1000 - PSNR: 26.62 dB
# Processing 344/1000 - PSNR: 27.53 dB
# Processing 345/1000 - PSNR: 26.48 dB
# Processing 346/1000 - PSNR: 27.03 dB
# Processing 347/1000 - PSNR: 26.26 dB
# Processing 348/1000 - PSNR: 27.06 dB
# Processing 349/1000 - PSNR: 26.30 dB
# Processing 350/1000 - PSNR: 26.65 dB
# Processing 351/1000 - PSNR: 26.97 dB
# Processing 352/1000 - PSNR: 23.91 dB
# Processing 353/1000 - PSNR: 26.80 dB
# Processing 354/1000 - PSNR: 25.45 dB
# Processing 355/1000 - PSNR: 24.60 dB
# Processing 356/1000 - PSNR: 26.41 dB
# Processing 357/1000 - PSNR: 28.29 dB
# Processing 358/1000 - PSNR: 25.17 dB
# Processing 359/1000 - PSNR: 26.86 dB
# Processing 360/1000 - PSNR: 25.93 dB
# Processing 361/1000 - PSNR: 26.63 dB
# Processing 362/1000 - PSNR: 24.32 dB
# Processing 363/1000 - PSNR: 26.27 dB
# Processing 364/1000 - PSNR: 26.62 dB
# Processing 365/1000 - PSNR: 26.31 dB
# Processing 366/1000 - PSNR: 24.63 dB
# Processing 367/1000 - PSNR: 24.05 dB
# Processing 368/1000 - PSNR: 26.41 dB
# Processing 369/1000 - PSNR: 24.61 dB
# Processing 370/1000 - PSNR: 25.21 dB
# Processing 371/1000 - PSNR: 27.75 dB
# Processing 372/1000 - PSNR: 26.75 dB
# Processing 373/1000 - PSNR: 25.93 dB
# Processing 374/1000 - PSNR: 23.84 dB
# Processing 375/1000 - PSNR: 25.19 dB
# Processing 376/1000 - PSNR: 25.78 dB
# Processing 377/1000 - PSNR: 26.67 dB
# Processing 378/1000 - PSNR: 27.23 dB
# Processing 379/1000 - PSNR: 28.04 dB
# Processing 380/1000 - PSNR: 26.77 dB
# Processing 381/1000 - PSNR: 26.47 dB
# Processing 382/1000 - PSNR: 25.17 dB
# Processing 383/1000 - PSNR: 26.91 dB
# Processing 384/1000 - PSNR: 27.94 dB
# Processing 385/1000 - PSNR: 27.61 dB
# Processing 386/1000 - PSNR: 25.76 dB
# Processing 387/1000 - PSNR: 26.02 dB
# Processing 388/1000 - PSNR: 26.69 dB
# Processing 389/1000 - PSNR: 25.65 dB
# Processing 390/1000 - PSNR: 26.89 dB
# Processing 391/1000 - PSNR: 25.09 dB
# Processing 392/1000 - PSNR: 26.97 dB
# Processing 393/1000 - PSNR: 25.80 dB
# Processing 394/1000 - PSNR: 28.30 dB
# Processing 395/1000 - PSNR: 26.89 dB
# Processing 396/1000 - PSNR: 26.35 dB
# Processing 397/1000 - PSNR: 27.20 dB
# Processing 398/1000 - PSNR: 26.47 dB
# Processing 399/1000 - PSNR: 26.87 dB
# Processing 400/1000 - PSNR: 26.78 dB
# Processing 401/1000 - PSNR: 25.76 dB
# Processing 402/1000 - PSNR: 26.39 dB
# Processing 403/1000 - PSNR: 26.51 dB
# Processing 404/1000 - PSNR: 30.12 dB
# Processing 405/1000 - PSNR: 24.77 dB
# Processing 406/1000 - PSNR: 26.99 dB
# Processing 407/1000 - PSNR: 27.68 dB
# Processing 408/1000 - PSNR: 25.02 dB
# Processing 409/1000 - PSNR: 26.51 dB
# Processing 410/1000 - PSNR: 28.11 dB
# Processing 411/1000 - PSNR: 27.09 dB
# Processing 412/1000 - PSNR: 25.07 dB
# Processing 413/1000 - PSNR: 26.78 dB
# Processing 414/1000 - PSNR: 26.44 dB
# Processing 415/1000 - PSNR: 28.72 dB
# Processing 416/1000 - PSNR: 24.82 dB
# Processing 417/1000 - PSNR: 26.63 dB
# Processing 418/1000 - PSNR: 24.23 dB
# Processing 419/1000 - PSNR: 25.02 dB
# Processing 420/1000 - PSNR: 24.68 dB
# Processing 421/1000 - PSNR: 27.98 dB
# Processing 422/1000 - PSNR: 25.25 dB
# Processing 423/1000 - PSNR: 24.62 dB
# Processing 424/1000 - PSNR: 23.17 dB
# Processing 425/1000 - PSNR: 27.62 dB
# Processing 426/1000 - PSNR: 26.06 dB
# Processing 427/1000 - PSNR: 29.06 dB
# Processing 428/1000 - PSNR: 27.23 dB
# Processing 429/1000 - PSNR: 24.06 dB
# Processing 430/1000 - PSNR: 28.31 dB
# Processing 431/1000 - PSNR: 27.00 dB
# Processing 432/1000 - PSNR: 24.97 dB
# Processing 433/1000 - PSNR: 26.63 dB
# Processing 434/1000 - PSNR: 26.64 dB
# Processing 435/1000 - PSNR: 27.53 dB
# Processing 436/1000 - PSNR: 25.68 dB
# Processing 437/1000 - PSNR: 25.48 dB
# Processing 438/1000 - PSNR: 28.42 dB
# Processing 439/1000 - PSNR: 26.20 dB
# Processing 440/1000 - PSNR: 24.25 dB
# Processing 441/1000 - PSNR: 27.21 dB
# Processing 442/1000 - PSNR: 26.43 dB
# Processing 443/1000 - PSNR: 27.45 dB
# Processing 444/1000 - PSNR: 28.88 dB
# Processing 445/1000 - PSNR: 25.17 dB
# Processing 446/1000 - PSNR: 25.95 dB
# Processing 447/1000 - PSNR: 24.34 dB
# Processing 448/1000 - PSNR: 25.63 dB
# Processing 449/1000 - PSNR: 27.76 dB
# Processing 450/1000 - PSNR: 27.60 dB
# Processing 451/1000 - PSNR: 27.67 dB
# Processing 452/1000 - PSNR: 27.99 dB
# Processing 453/1000 - PSNR: 26.78 dB
# Processing 454/1000 - PSNR: 24.38 dB
# Processing 455/1000 - PSNR: 25.92 dB
# Processing 456/1000 - PSNR: 23.64 dB
# Processing 457/1000 - PSNR: 25.33 dB
# Processing 458/1000 - PSNR: 28.98 dB
# Processing 459/1000 - PSNR: 30.45 dB
# Processing 460/1000 - PSNR: 23.96 dB
# Processing 461/1000 - PSNR: 26.60 dB
# Processing 462/1000 - PSNR: 26.54 dB
# Processing 463/1000 - PSNR: 27.92 dB
# Processing 464/1000 - PSNR: 27.92 dB
# Processing 465/1000 - PSNR: 26.58 dB
# Processing 466/1000 - PSNR: 25.38 dB
# Processing 467/1000 - PSNR: 27.13 dB
# Processing 468/1000 - PSNR: 26.36 dB
# Processing 469/1000 - PSNR: 26.13 dB
# Processing 470/1000 - PSNR: 26.56 dB
# Processing 471/1000 - PSNR: 25.75 dB
# Processing 472/1000 - PSNR: 26.71 dB
# Processing 473/1000 - PSNR: 26.58 dB
# Processing 474/1000 - PSNR: 27.52 dB
# Processing 475/1000 - PSNR: 27.24 dB
# Processing 476/1000 - PSNR: 27.97 dB
# Processing 477/1000 - PSNR: 25.80 dB
# Processing 478/1000 - PSNR: 27.20 dB
# Processing 479/1000 - PSNR: 26.89 dB
# Processing 480/1000 - PSNR: 25.46 dB
# Processing 481/1000 - PSNR: 26.24 dB
# Processing 482/1000 - PSNR: 26.53 dB
# Processing 483/1000 - PSNR: 25.17 dB
# Processing 484/1000 - PSNR: 27.22 dB
# Processing 485/1000 - PSNR: 23.73 dB
# Processing 486/1000 - PSNR: 25.92 dB
# Processing 487/1000 - PSNR: 25.57 dB
# Processing 488/1000 - PSNR: 26.06 dB
# Processing 489/1000 - PSNR: 25.08 dB
# Processing 490/1000 - PSNR: 26.35 dB
# Processing 491/1000 - PSNR: 25.44 dB
# Processing 492/1000 - PSNR: 26.56 dB
# Processing 493/1000 - PSNR: 27.69 dB
# Processing 494/1000 - PSNR: 26.02 dB
# Processing 495/1000 - PSNR: 23.85 dB
# Processing 496/1000 - PSNR: 26.60 dB
# Processing 497/1000 - PSNR: 24.66 dB
# Processing 498/1000 - PSNR: 26.64 dB
# Processing 499/1000 - PSNR: 27.50 dB
# Processing 500/1000 - PSNR: 28.74 dB
# Processing 501/1000 - PSNR: 25.44 dB
# Processing 502/1000 - PSNR: 26.95 dB
# Processing 503/1000 - PSNR: 23.99 dB
# Processing 504/1000 - PSNR: 25.39 dB
# Processing 505/1000 - PSNR: 25.84 dB
# Processing 506/1000 - PSNR: 26.56 dB
# Processing 507/1000 - PSNR: 29.42 dB
# Processing 508/1000 - PSNR: 28.13 dB
# Processing 509/1000 - PSNR: 26.80 dB
# Processing 510/1000 - PSNR: 24.88 dB
# Processing 511/1000 - PSNR: 27.00 dB
# Processing 512/1000 - PSNR: 26.30 dB
# Processing 513/1000 - PSNR: 25.39 dB
# Processing 514/1000 - PSNR: 26.35 dB
# Processing 515/1000 - PSNR: 28.54 dB
# Processing 516/1000 - PSNR: 26.79 dB
# Processing 517/1000 - PSNR: 26.60 dB
# Processing 518/1000 - PSNR: 26.53 dB
# Processing 519/1000 - PSNR: 27.21 dB
# Processing 520/1000 - PSNR: 27.22 dB
# Processing 521/1000 - PSNR: 28.06 dB
# Processing 522/1000 - PSNR: 26.02 dB
# Processing 523/1000 - PSNR: 27.18 dB
# Processing 524/1000 - PSNR: 25.50 dB
# Processing 525/1000 - PSNR: 26.08 dB
# Processing 526/1000 - PSNR: 27.11 dB
# Processing 527/1000 - PSNR: 26.87 dB
# Processing 528/1000 - PSNR: 25.68 dB
# Processing 529/1000 - PSNR: 24.13 dB
# Processing 530/1000 - PSNR: 25.25 dB
# Processing 531/1000 - PSNR: 27.72 dB
# Processing 532/1000 - PSNR: 24.30 dB
# Processing 533/1000 - PSNR: 24.51 dB
# Processing 534/1000 - PSNR: 26.78 dB
# Processing 535/1000 - PSNR: 27.22 dB
# Processing 536/1000 - PSNR: 28.71 dB
# Processing 537/1000 - PSNR: 26.03 dB
# Processing 538/1000 - PSNR: 26.01 dB
# Processing 539/1000 - PSNR: 26.63 dB
# Processing 540/1000 - PSNR: 26.24 dB
# Processing 541/1000 - PSNR: 28.24 dB
# Processing 542/1000 - PSNR: 27.42 dB
# Processing 543/1000 - PSNR: 26.04 dB
# Processing 544/1000 - PSNR: 27.49 dB
# Processing 545/1000 - PSNR: 25.93 dB
# Processing 546/1000 - PSNR: 24.21 dB
# Processing 547/1000 - PSNR: 26.99 dB
# Processing 548/1000 - PSNR: 25.83 dB
# Processing 549/1000 - PSNR: 27.48 dB
# Processing 550/1000 - PSNR: 25.28 dB
# Processing 551/1000 - PSNR: 26.99 dB
# Processing 552/1000 - PSNR: 27.44 dB
# Processing 553/1000 - PSNR: 24.13 dB
# Processing 554/1000 - PSNR: 26.85 dB
# Processing 555/1000 - PSNR: 26.17 dB
# Processing 556/1000 - PSNR: 26.15 dB
# Processing 557/1000 - PSNR: 27.30 dB
# Processing 558/1000 - PSNR: 25.24 dB
# Processing 559/1000 - PSNR: 25.59 dB
# Processing 560/1000 - PSNR: 25.49 dB
# Processing 561/1000 - PSNR: 25.05 dB
# Processing 562/1000 - PSNR: 27.46 dB
# Processing 563/1000 - PSNR: 25.62 dB
# Processing 564/1000 - PSNR: 24.67 dB
# Processing 565/1000 - PSNR: 26.05 dB
# Processing 566/1000 - PSNR: 25.99 dB
# Processing 567/1000 - PSNR: 25.60 dB
# Processing 568/1000 - PSNR: 26.77 dB
# Processing 569/1000 - PSNR: 27.05 dB
# Processing 570/1000 - PSNR: 25.03 dB
# Processing 571/1000 - PSNR: 26.98 dB
# Processing 572/1000 - PSNR: 24.19 dB
# Processing 573/1000 - PSNR: 24.99 dB
# Processing 574/1000 - PSNR: 24.61 dB
# Processing 575/1000 - PSNR: 27.42 dB
# Processing 576/1000 - PSNR: 28.01 dB
# Processing 577/1000 - PSNR: 26.94 dB
# Processing 578/1000 - PSNR: 26.30 dB
# Processing 579/1000 - PSNR: 26.73 dB
# Processing 580/1000 - PSNR: 27.63 dB
# Processing 581/1000 - PSNR: 27.61 dB
# Processing 582/1000 - PSNR: 26.52 dB
# Processing 583/1000 - PSNR: 24.73 dB
# Processing 584/1000 - PSNR: 25.95 dB
# Processing 585/1000 - PSNR: 26.53 dB
# Processing 586/1000 - PSNR: 26.74 dB
# Processing 587/1000 - PSNR: 25.31 dB
# Processing 588/1000 - PSNR: 23.95 dB
# Processing 589/1000 - PSNR: 27.33 dB
# Processing 590/1000 - PSNR: 24.97 dB
# Processing 591/1000 - PSNR: 26.86 dB
# Processing 592/1000 - PSNR: 24.71 dB
# Processing 593/1000 - PSNR: 27.77 dB
# Processing 594/1000 - PSNR: 25.02 dB
# Processing 595/1000 - PSNR: 26.34 dB
# Processing 596/1000 - PSNR: 25.91 dB
# Processing 597/1000 - PSNR: 24.31 dB
# Processing 598/1000 - PSNR: 26.19 dB
# Processing 599/1000 - PSNR: 26.59 dB
# Processing 600/1000 - PSNR: 26.20 dB
# Processing 601/1000 - PSNR: 27.88 dB
# Processing 602/1000 - PSNR: 25.57 dB
# Processing 603/1000 - PSNR: 25.72 dB
# Processing 604/1000 - PSNR: 27.21 dB
# Processing 605/1000 - PSNR: 25.48 dB
# Processing 606/1000 - PSNR: 26.49 dB
# Processing 607/1000 - PSNR: 27.68 dB
# Processing 608/1000 - PSNR: 28.29 dB
# Processing 609/1000 - PSNR: 25.72 dB
# Processing 610/1000 - PSNR: 25.52 dB
# Processing 611/1000 - PSNR: 25.77 dB
# Processing 612/1000 - PSNR: 25.60 dB
# Processing 613/1000 - PSNR: 24.90 dB
# Processing 614/1000 - PSNR: 25.99 dB
# Processing 615/1000 - PSNR: 25.28 dB
# Processing 616/1000 - PSNR: 27.78 dB
# Processing 617/1000 - PSNR: 26.22 dB
# Processing 618/1000 - PSNR: 24.73 dB
# Processing 619/1000 - PSNR: 27.23 dB
# Processing 620/1000 - PSNR: 26.69 dB
# Processing 621/1000 - PSNR: 27.84 dB
# Processing 622/1000 - PSNR: 25.73 dB
# Processing 623/1000 - PSNR: 26.31 dB
# Processing 624/1000 - PSNR: 23.17 dB
# Processing 625/1000 - PSNR: 24.40 dB
# Processing 626/1000 - PSNR: 26.81 dB
# Processing 627/1000 - PSNR: 27.10 dB
# Processing 628/1000 - PSNR: 26.63 dB
# Processing 629/1000 - PSNR: 25.25 dB
# Processing 630/1000 - PSNR: 27.31 dB
# Processing 631/1000 - PSNR: 25.85 dB
# Processing 632/1000 - PSNR: 24.82 dB
# Processing 633/1000 - PSNR: 23.36 dB
# Processing 634/1000 - PSNR: 25.91 dB
# Processing 635/1000 - PSNR: 25.87 dB
# Processing 636/1000 - PSNR: 28.29 dB
# Processing 637/1000 - PSNR: 25.97 dB
# Processing 638/1000 - PSNR: 27.38 dB
# Processing 639/1000 - PSNR: 26.60 dB
# Processing 640/1000 - PSNR: 25.67 dB
# Processing 641/1000 - PSNR: 24.50 dB
# Processing 642/1000 - PSNR: 26.53 dB
# Processing 643/1000 - PSNR: 25.94 dB
# Processing 644/1000 - PSNR: 26.85 dB
# Processing 645/1000 - PSNR: 23.33 dB
# Processing 646/1000 - PSNR: 26.52 dB
# Processing 647/1000 - PSNR: 27.34 dB
# Processing 648/1000 - PSNR: 25.00 dB
# Processing 649/1000 - PSNR: 25.70 dB
# Processing 650/1000 - PSNR: 25.84 dB
# Processing 651/1000 - PSNR: 27.04 dB
# Processing 652/1000 - PSNR: 26.63 dB
# Processing 653/1000 - PSNR: 25.78 dB
# Processing 654/1000 - PSNR: 27.01 dB
# Processing 655/1000 - PSNR: 25.37 dB
# Processing 656/1000 - PSNR: 26.10 dB
# Processing 657/1000 - PSNR: 26.97 dB
# Processing 658/1000 - PSNR: 27.16 dB
# Processing 659/1000 - PSNR: 23.72 dB
# Processing 660/1000 - PSNR: 28.14 dB
# Processing 661/1000 - PSNR: 25.02 dB
# Processing 662/1000 - PSNR: 25.16 dB
# Processing 663/1000 - PSNR: 26.21 dB
# Processing 664/1000 - PSNR: 28.35 dB
# Processing 665/1000 - PSNR: 26.71 dB
# Processing 666/1000 - PSNR: 28.08 dB
# Processing 667/1000 - PSNR: 26.65 dB
# Processing 668/1000 - PSNR: 24.59 dB
# Processing 669/1000 - PSNR: 26.01 dB
# Processing 670/1000 - PSNR: 24.64 dB
# Processing 671/1000 - PSNR: 24.91 dB
# Processing 672/1000 - PSNR: 23.92 dB
# Processing 673/1000 - PSNR: 24.88 dB
# Processing 674/1000 - PSNR: 28.00 dB
# Processing 675/1000 - PSNR: 25.65 dB
# Processing 676/1000 - PSNR: 27.09 dB
# Processing 677/1000 - PSNR: 25.25 dB
# Processing 678/1000 - PSNR: 26.48 dB
# Processing 679/1000 - PSNR: 23.97 dB
# Processing 680/1000 - PSNR: 27.66 dB
# Processing 681/1000 - PSNR: 24.16 dB
# Processing 682/1000 - PSNR: 24.17 dB
# Processing 683/1000 - PSNR: 24.04 dB
# Processing 684/1000 - PSNR: 30.32 dB
# Processing 685/1000 - PSNR: 26.20 dB
# Processing 686/1000 - PSNR: 26.14 dB
# Processing 687/1000 - PSNR: 27.87 dB
# Processing 688/1000 - PSNR: 24.51 dB
# Processing 689/1000 - PSNR: 26.10 dB
# Processing 690/1000 - PSNR: 24.92 dB
# Processing 691/1000 - PSNR: 29.97 dB
# Processing 692/1000 - PSNR: 23.85 dB
# Processing 693/1000 - PSNR: 27.90 dB
# Processing 694/1000 - PSNR: 27.31 dB
# Processing 695/1000 - PSNR: 26.91 dB
# Processing 696/1000 - PSNR: 27.23 dB
# Processing 697/1000 - PSNR: 27.86 dB
# Processing 698/1000 - PSNR: 25.94 dB
# Processing 699/1000 - PSNR: 25.55 dB
# Processing 700/1000 - PSNR: 27.92 dB
# Processing 701/1000 - PSNR: 28.17 dB
# Processing 702/1000 - PSNR: 28.05 dB
# Processing 703/1000 - PSNR: 27.25 dB
# Processing 704/1000 - PSNR: 26.47 dB
# Processing 705/1000 - PSNR: 26.00 dB
# Processing 706/1000 - PSNR: 25.78 dB
# Processing 707/1000 - PSNR: 26.76 dB
# Processing 708/1000 - PSNR: 25.31 dB
# Processing 709/1000 - PSNR: 27.37 dB
# Processing 710/1000 - PSNR: 23.63 dB
# Processing 711/1000 - PSNR: 25.33 dB
# Processing 712/1000 - PSNR: 26.44 dB
# Processing 713/1000 - PSNR: 24.27 dB
# Processing 714/1000 - PSNR: 26.88 dB
# Processing 715/1000 - PSNR: 26.52 dB
# Processing 716/1000 - PSNR: 25.04 dB
# Processing 717/1000 - PSNR: 25.52 dB
# Processing 718/1000 - PSNR: 26.03 dB
# Processing 719/1000 - PSNR: 28.13 dB
# Processing 720/1000 - PSNR: 24.39 dB
# Processing 721/1000 - PSNR: 26.62 dB
# Processing 722/1000 - PSNR: 25.56 dB
# Processing 723/1000 - PSNR: 25.50 dB
# Processing 724/1000 - PSNR: 24.73 dB
# Processing 725/1000 - PSNR: 26.44 dB
# Processing 726/1000 - PSNR: 22.69 dB
# Processing 727/1000 - PSNR: 26.82 dB
# Processing 728/1000 - PSNR: 28.73 dB
# Processing 729/1000 - PSNR: 25.19 dB
# Processing 730/1000 - PSNR: 25.88 dB
# Processing 731/1000 - PSNR: 28.17 dB
# Processing 732/1000 - PSNR: 27.51 dB
# Processing 733/1000 - PSNR: 26.32 dB
# Processing 734/1000 - PSNR: 27.72 dB
# Processing 735/1000 - PSNR: 25.44 dB
# Processing 736/1000 - PSNR: 26.68 dB
# Processing 737/1000 - PSNR: 25.68 dB
# Processing 738/1000 - PSNR: 26.80 dB
# Processing 739/1000 - PSNR: 28.43 dB
# Processing 740/1000 - PSNR: 25.96 dB
# Processing 741/1000 - PSNR: 27.93 dB
# Processing 742/1000 - PSNR: 27.12 dB
# Processing 743/1000 - PSNR: 28.16 dB
# Processing 744/1000 - PSNR: 26.19 dB
# Processing 745/1000 - PSNR: 26.88 dB
# Processing 746/1000 - PSNR: 27.03 dB
# Processing 747/1000 - PSNR: 25.27 dB
# Processing 748/1000 - PSNR: 25.40 dB
# Processing 749/1000 - PSNR: 25.07 dB
# Processing 750/1000 - PSNR: 30.08 dB
# Processing 751/1000 - PSNR: 24.45 dB
# Processing 752/1000 - PSNR: 23.29 dB
# Processing 753/1000 - PSNR: 27.28 dB
# Processing 754/1000 - PSNR: 24.58 dB
# Processing 755/1000 - PSNR: 26.47 dB
# Processing 756/1000 - PSNR: 25.83 dB
# Processing 757/1000 - PSNR: 27.78 dB
# Processing 758/1000 - PSNR: 26.04 dB
# Processing 759/1000 - PSNR: 26.27 dB
# Processing 760/1000 - PSNR: 27.00 dB
# Processing 761/1000 - PSNR: 27.70 dB
# Processing 762/1000 - PSNR: 26.47 dB
# Processing 763/1000 - PSNR: 28.24 dB
# Processing 764/1000 - PSNR: 23.37 dB
# Processing 765/1000 - PSNR: 28.65 dB
# Processing 766/1000 - PSNR: 26.42 dB
# Processing 767/1000 - PSNR: 25.59 dB
# Processing 768/1000 - PSNR: 24.26 dB
# Processing 769/1000 - PSNR: 27.83 dB
# Processing 770/1000 - PSNR: 28.15 dB
# Processing 771/1000 - PSNR: 27.95 dB
# Processing 772/1000 - PSNR: 27.48 dB
# Processing 773/1000 - PSNR: 26.26 dB
# Processing 774/1000 - PSNR: 25.66 dB
# Processing 775/1000 - PSNR: 25.58 dB
# Processing 776/1000 - PSNR: 24.23 dB
# Processing 777/1000 - PSNR: 27.13 dB
# Processing 778/1000 - PSNR: 30.95 dB
# Processing 779/1000 - PSNR: 27.57 dB
# Processing 780/1000 - PSNR: 26.34 dB
# Processing 781/1000 - PSNR: 27.56 dB
# Processing 782/1000 - PSNR: 24.96 dB
# Processing 783/1000 - PSNR: 25.87 dB
# Processing 784/1000 - PSNR: 25.38 dB
# Processing 785/1000 - PSNR: 28.11 dB
# Processing 786/1000 - PSNR: 28.00 dB
# Processing 787/1000 - PSNR: 26.98 dB
# Processing 788/1000 - PSNR: 24.67 dB
# Processing 789/1000 - PSNR: 26.75 dB
# Processing 790/1000 - PSNR: 25.53 dB
# Processing 791/1000 - PSNR: 24.14 dB
# Processing 792/1000 - PSNR: 26.30 dB
# Processing 793/1000 - PSNR: 27.09 dB
# Processing 794/1000 - PSNR: 25.89 dB
# Processing 795/1000 - PSNR: 24.42 dB
# Processing 796/1000 - PSNR: 28.00 dB
# Processing 797/1000 - PSNR: 27.97 dB
# Processing 798/1000 - PSNR: 27.59 dB
# Processing 799/1000 - PSNR: 29.06 dB
# Processing 800/1000 - PSNR: 28.17 dB
# Processing 801/1000 - PSNR: 27.15 dB
# Processing 802/1000 - PSNR: 25.84 dB
# Processing 803/1000 - PSNR: 25.59 dB
# Processing 804/1000 - PSNR: 25.84 dB
# Processing 805/1000 - PSNR: 29.03 dB
# Processing 806/1000 - PSNR: 27.80 dB
# Processing 807/1000 - PSNR: 24.48 dB
# Processing 808/1000 - PSNR: 25.40 dB
# Processing 809/1000 - PSNR: 26.36 dB
# Processing 810/1000 - PSNR: 24.92 dB
# Processing 811/1000 - PSNR: 24.49 dB
# Processing 812/1000 - PSNR: 26.88 dB
# Processing 813/1000 - PSNR: 25.67 dB
# Processing 814/1000 - PSNR: 26.55 dB
# Processing 815/1000 - PSNR: 26.78 dB
# Processing 816/1000 - PSNR: 25.67 dB
# Processing 817/1000 - PSNR: 26.08 dB
# Processing 818/1000 - PSNR: 29.38 dB
# Processing 819/1000 - PSNR: 28.28 dB
# Processing 820/1000 - PSNR: 26.26 dB
# Processing 821/1000 - PSNR: 23.91 dB
# Processing 822/1000 - PSNR: 27.20 dB
# Processing 823/1000 - PSNR: 27.05 dB
# Processing 824/1000 - PSNR: 25.97 dB
# Processing 825/1000 - PSNR: 26.99 dB
# Processing 826/1000 - PSNR: 27.10 dB
# Processing 827/1000 - PSNR: 26.73 dB
# Processing 828/1000 - PSNR: 25.92 dB
# Processing 829/1000 - PSNR: 25.70 dB
# Processing 830/1000 - PSNR: 25.82 dB
# Processing 831/1000 - PSNR: 25.22 dB
# Processing 832/1000 - PSNR: 28.87 dB
# Processing 833/1000 - PSNR: 24.92 dB
# Processing 834/1000 - PSNR: 27.31 dB
# Processing 835/1000 - PSNR: 25.10 dB
# Processing 836/1000 - PSNR: 23.50 dB
# Processing 837/1000 - PSNR: 25.34 dB
# Processing 838/1000 - PSNR: 27.70 dB
# Processing 839/1000 - PSNR: 26.26 dB
# Processing 840/1000 - PSNR: 27.39 dB
# Processing 841/1000 - PSNR: 24.57 dB
# Processing 842/1000 - PSNR: 25.09 dB
# Processing 843/1000 - PSNR: 26.31 dB
# Processing 844/1000 - PSNR: 24.23 dB
# Processing 845/1000 - PSNR: 27.10 dB
# Processing 846/1000 - PSNR: 26.14 dB
# Processing 847/1000 - PSNR: 27.83 dB
# Processing 848/1000 - PSNR: 26.70 dB
# Processing 849/1000 - PSNR: 26.52 dB
# Processing 850/1000 - PSNR: 25.79 dB
# Processing 851/1000 - PSNR: 25.81 dB
# Processing 852/1000 - PSNR: 26.19 dB
# Processing 853/1000 - PSNR: 27.35 dB
# Processing 854/1000 - PSNR: 25.50 dB
# Processing 855/1000 - PSNR: 25.45 dB
# Processing 856/1000 - PSNR: 26.36 dB
# Processing 857/1000 - PSNR: 27.40 dB
# Processing 858/1000 - PSNR: 29.00 dB
# Processing 859/1000 - PSNR: 27.04 dB
# Processing 860/1000 - PSNR: 26.79 dB
# Processing 861/1000 - PSNR: 25.01 dB
# Processing 862/1000 - PSNR: 26.51 dB
# Processing 863/1000 - PSNR: 23.55 dB
# Processing 864/1000 - PSNR: 25.80 dB
# Processing 865/1000 - PSNR: 27.27 dB
# Processing 866/1000 - PSNR: 25.97 dB
# Processing 867/1000 - PSNR: 27.65 dB
# Processing 868/1000 - PSNR: 26.50 dB
# Processing 869/1000 - PSNR: 27.23 dB
# Processing 870/1000 - PSNR: 26.24 dB
# Processing 871/1000 - PSNR: 27.65 dB
# Processing 872/1000 - PSNR: 26.79 dB
# Processing 873/1000 - PSNR: 25.37 dB
# Processing 874/1000 - PSNR: 27.18 dB
# Processing 875/1000 - PSNR: 26.56 dB
# Processing 876/1000 - PSNR: 26.79 dB
# Processing 877/1000 - PSNR: 27.47 dB
# Processing 878/1000 - PSNR: 25.31 dB
# Processing 879/1000 - PSNR: 24.06 dB
# Processing 880/1000 - PSNR: 25.91 dB
# Processing 881/1000 - PSNR: 24.75 dB
# Processing 882/1000 - PSNR: 25.47 dB
# Processing 883/1000 - PSNR: 26.48 dB
# Processing 884/1000 - PSNR: 26.41 dB
# Processing 885/1000 - PSNR: 28.10 dB
# Processing 886/1000 - PSNR: 23.64 dB
# Processing 887/1000 - PSNR: 26.28 dB
# Processing 888/1000 - PSNR: 25.72 dB
# Processing 889/1000 - PSNR: 27.28 dB
# Processing 890/1000 - PSNR: 25.22 dB
# Processing 891/1000 - PSNR: 30.68 dB
# Processing 892/1000 - PSNR: 24.93 dB
# Processing 893/1000 - PSNR: 26.22 dB
# Processing 894/1000 - PSNR: 25.91 dB
# Processing 895/1000 - PSNR: 27.06 dB
# Processing 896/1000 - PSNR: 27.86 dB
# Processing 897/1000 - PSNR: 26.17 dB
# Processing 898/1000 - PSNR: 27.76 dB
# Processing 899/1000 - PSNR: 27.22 dB
# Processing 900/1000 - PSNR: 28.67 dB
# Processing 901/1000 - PSNR: 25.38 dB
# Processing 902/1000 - PSNR: 26.87 dB
# Processing 903/1000 - PSNR: 25.93 dB
# Processing 904/1000 - PSNR: 24.61 dB
# Processing 905/1000 - PSNR: 27.47 dB
# Processing 906/1000 - PSNR: 25.96 dB
# Processing 907/1000 - PSNR: 26.28 dB
# Processing 908/1000 - PSNR: 28.33 dB
# Processing 909/1000 - PSNR: 26.75 dB
# Processing 910/1000 - PSNR: 25.20 dB
# Processing 911/1000 - PSNR: 26.69 dB
# Processing 912/1000 - PSNR: 25.98 dB
# Processing 913/1000 - PSNR: 24.23 dB
# Processing 914/1000 - PSNR: 26.36 dB
# Processing 915/1000 - PSNR: 27.85 dB
# Processing 916/1000 - PSNR: 26.58 dB
# Processing 917/1000 - PSNR: 27.04 dB
# Processing 918/1000 - PSNR: 27.28 dB
# Processing 919/1000 - PSNR: 27.11 dB
# Processing 920/1000 - PSNR: 25.63 dB
# Processing 921/1000 - PSNR: 28.22 dB
# Processing 922/1000 - PSNR: 27.32 dB
# Processing 923/1000 - PSNR: 25.36 dB
# Processing 924/1000 - PSNR: 26.65 dB
# Processing 925/1000 - PSNR: 24.96 dB
# Processing 926/1000 - PSNR: 25.14 dB
# Processing 927/1000 - PSNR: 25.76 dB
# Processing 928/1000 - PSNR: 25.64 dB
# Processing 929/1000 - PSNR: 27.17 dB
# Processing 930/1000 - PSNR: 25.89 dB
# Processing 931/1000 - PSNR: 29.05 dB
# Processing 932/1000 - PSNR: 29.44 dB
# Processing 933/1000 - PSNR: 25.44 dB
# Processing 934/1000 - PSNR: 28.71 dB
# Processing 935/1000 - PSNR: 25.72 dB
# Processing 936/1000 - PSNR: 26.64 dB
# Processing 937/1000 - PSNR: 25.94 dB
# Processing 938/1000 - PSNR: 24.73 dB
# Processing 939/1000 - PSNR: 24.28 dB
# Processing 940/1000 - PSNR: 25.70 dB
# Processing 941/1000 - PSNR: 27.37 dB
# Processing 942/1000 - PSNR: 25.55 dB
# Processing 943/1000 - PSNR: 26.06 dB
# Processing 944/1000 - PSNR: 27.00 dB
# Processing 945/1000 - PSNR: 26.18 dB
# Processing 946/1000 - PSNR: 27.39 dB
# Processing 947/1000 - PSNR: 26.17 dB
# Processing 948/1000 - PSNR: 26.60 dB
# Processing 949/1000 - PSNR: 24.05 dB
# Processing 950/1000 - PSNR: 25.28 dB
# Processing 951/1000 - PSNR: 27.41 dB
# Processing 952/1000 - PSNR: 24.63 dB
# Processing 953/1000 - PSNR: 26.15 dB
# Processing 954/1000 - PSNR: 29.12 dB
# Processing 955/1000 - PSNR: 27.24 dB
# Processing 956/1000 - PSNR: 27.94 dB
# Processing 957/1000 - PSNR: 28.45 dB
# Processing 958/1000 - PSNR: 25.61 dB
# Processing 959/1000 - PSNR: 28.17 dB
# Processing 960/1000 - PSNR: 26.27 dB
# Processing 961/1000 - PSNR: 25.33 dB
# Processing 962/1000 - PSNR: 25.02 dB
# Processing 963/1000 - PSNR: 25.10 dB
# Processing 964/1000 - PSNR: 25.75 dB
# Processing 965/1000 - PSNR: 25.61 dB
# Processing 966/1000 - PSNR: 24.80 dB
# Processing 967/1000 - PSNR: 26.34 dB
# Processing 968/1000 - PSNR: 24.89 dB
# Processing 969/1000 - PSNR: 25.38 dB
# Processing 970/1000 - PSNR: 27.34 dB
# Processing 971/1000 - PSNR: 26.43 dB
# Processing 972/1000 - PSNR: 27.02 dB
# Processing 973/1000 - PSNR: 24.62 dB
# Processing 974/1000 - PSNR: 26.69 dB
# Processing 975/1000 - PSNR: 24.87 dB
# Processing 976/1000 - PSNR: 26.77 dB
# Processing 977/1000 - PSNR: 26.10 dB
# Processing 978/1000 - PSNR: 25.44 dB
# Processing 979/1000 - PSNR: 27.18 dB
# Processing 980/1000 - PSNR: 27.60 dB
# Processing 981/1000 - PSNR: 26.19 dB
# Processing 982/1000 - PSNR: 26.50 dB
# Processing 983/1000 - PSNR: 26.99 dB
# Processing 984/1000 - PSNR: 25.44 dB
# Processing 985/1000 - PSNR: 27.67 dB
# Processing 986/1000 - PSNR: 26.38 dB
# Processing 987/1000 - PSNR: 25.99 dB
# Processing 988/1000 - PSNR: 25.68 dB
# Processing 989/1000 - PSNR: 26.49 dB
# Processing 990/1000 - PSNR: 26.64 dB
# Processing 991/1000 - PSNR: 29.02 dB
# Processing 992/1000 - PSNR: 23.30 dB
# Processing 993/1000 - PSNR: 25.29 dB
# Processing 994/1000 - PSNR: 26.58 dB
# Processing 995/1000 - PSNR: 25.44 dB
# Processing 996/1000 - PSNR: 26.63 dB
# Processing 997/1000 - PSNR: 28.13 dB
# Processing 998/1000 - PSNR: 25.44 dB
# Processing 999/1000 - PSNR: 24.89 dB
# Processing 1000/1000 - PSNR: 23.63 dB
# dropping last batch
#
# Test completed
# Mean PSNR over 1000 images: 26.34 dB

# %%
if TEST:
  for batch in test_loader:
      gt_tensor_norm = batch.to(device)
      curr_batch_size = min(gt_tensor_norm.shape[0], max_test_images - processed_images)
      print(f"batch shape: {gt_tensor_norm.shape}")
      print(f"curr_batch_size: {curr_batch_size}")
      print(f"processed_images: {processed_images}")
      break
# Out:
# batch shape: torch.Size([8, 3, 128, 128])
# curr_batch_size: 0
# processed_images: 1000

# %%
if TEST:
    print(f"Media PSNR: {np.mean(results_psnr):.2f}")

    worst_5_psnr_values = [f"{item['psnr']:.2f}" for item in worst_results[:5]]
    print(f"Worst 5 PSNR: {', '.join(worst_5_psnr_values)}")

    best_5_psnr_values = [f"{item['psnr']:.2f}" for item in best_results[:5]]
    print(f"Best 5 PSNR: {', '.join(best_5_psnr_values)}")
# Out:
# Media PSNR: 26.34
# Worst 5 PSNR: 22.69, 22.69, 22.74, 22.90, 23.00
# Best 5 PSNR: 30.95, 30.68, 30.47, 30.45, 30.32

# %%
# BEST
if TEST:
    b = best_results[0]

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title(f"Originale")
    plt.imshow(b['gt'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    # Normalize b['gt'] from [0, 1] to [-1, 1] before passing to jpeg_degradation
    normalized_gt = (b['gt'] * 2) - 1
    jpeg_degradation(None, 0)
    b['degraded'] = jpeg_degradation(normalized_gt, 9)

    plt.subplot(1, 3, 2)
    plt.title(f"Degradata (Input)")
    # Denormalize for display: from [-1, 1] back to [0, 1]
    img_display = ((b['degraded'].squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().detach().clamp(0, 1)
    plt.imshow(img_display)

    plt.subplot(1, 3, 3)
    plt.title(f"Restaurata (Output) - PSNR: {b['psnr']:.2f}")
    plt.imshow(b['restored'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    plt.show()

# %%
# BEST
if TEST:
    b = best_results[0]

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title(f"Originale")
    plt.imshow(b['gt'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    # Normalize b['gt'] from [0, 1] to [-1, 1] before passing to jpeg_degradation
    normalized_gt = (b['gt'] * 2) - 1
    jpeg_degradation(None, 0)
    b['degraded'] = jpeg_degradation(normalized_gt, 9)

    plt.subplot(1, 3, 2)
    plt.title(f"Degradata (Input)")
    # Denormalize for display: from [-1, 1] back to [0, 1]
    img_display = ((b['degraded'].squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().detach().clamp(0, 1)
    plt.imshow(img_display)

    plt.subplot(1, 3, 3)
    plt.title(f"Restaurata (Output) - PSNR: {b['psnr']:.2f}")
    plt.imshow(b['restored'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    plt.show()
