# %% [markdown]
# # Contents
# The degradation function here is implemented with the jpegio library. It requires a lot of RAM, I had to restart the training several times.
#
# Each step sets a coefficient to zero.

# %%
TRAIN = False
TEST = True

# %% [markdown]
# # Imports
# Installing libraries, importing them

# %%
! pip install torch torchvision
! pip install matplotlib
! pip install comet_ml
! pip install einops
! pip install torchgeometry
! pip install jpegio
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (0.26.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch) (12.8.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torchvision) (2.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting comet_ml
#   Downloading comet_ml-3.58.6-py3-none-any.whl.metadata (4.0 kB)
# Collecting dulwich!=0.20.33,>=0.20.6 (from comet_ml)
#   Downloading dulwich-1.2.14-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (6.0 kB)
# Collecting everett<3.2.0,>=1.0.1 (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading everett-3.1.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (4.26.0)
# Requirement already satisfied: psutil>=5.6.3 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (5.9.5)
# Collecting python-box<7.0.0 (from comet_ml)
#   Downloading python_box-6.1.0-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: requests-toolbelt>=0.8.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (1.0.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.32.4)
# Requirement already satisfied: rich>=13.3.2 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (13.9.4)
# Requirement already satisfied: semantic-version>=2.8.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.10.0)
# Requirement already satisfied: sentry-sdk>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.68.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from comet_ml) (75.2.0)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.13/dist-packages (from comet_ml) (4.1.1)
# Requirement already satisfied: urllib3>=1.26.8 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.13/dist-packages (from comet_ml) (2.3.0)
# Collecting wurlitzer>=1.0.2 (from comet_ml)
#   Downloading wurlitzer-3.1.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting configobj (from everett[ini]<3.2.0,>=1.0.1->comet_ml)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (2026.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (3.19)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests>=2.18.4->comet_ml) (2026.7.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.3.2->comet_ml) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.3.2->comet_ml) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.3.2->comet_ml) (0.1.2)
# Downloading comet_ml-3.58.6-py3-none-any.whl (829 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.7/829.7 kB 22.5 MB/s eta 0:00:00
# Downloading dulwich-1.2.14-cp313-cp313-manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 73.0 MB/s eta 0:00:00
# Downloading everett-3.1.0-py2.py3-none-any.whl (35 kB)
# Downloading python_box-6.1.0-py3-none-any.whl (27 kB)
# Downloading wurlitzer-3.1.1-py3-none-any.whl (8.6 kB)
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Installing collected packages: everett, wurlitzer, python-box, dulwich, configobj, comet_ml
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.4.1
#     Uninstalling python-box-7.4.1:
#       Successfully uninstalled python-box-7.4.1
# Successfully installed comet_ml-3.58.6 configobj-5.0.9 dulwich-1.2.14 everett-3.1.0 python-box-6.1.0 wurlitzer-3.1.1
# Requirement already satisfied: einops in /usr/local/lib/python3.13/dist-packages (0.8.2)
# Collecting torchgeometry
#   Downloading torchgeometry-0.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from torchgeometry) (2.11.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.32.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=1.0.0->torchgeometry) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.0.0->torchgeometry) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.0.0->torchgeometry) (1.7.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=1.0.0->torchgeometry) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=1.0.0->torchgeometry) (3.0.3)
# Downloading torchgeometry-0.1.2-py2.py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: torchgeometry
# Successfully installed torchgeometry-0.1.2
# Collecting jpegio
#   Downloading jpegio-0.2.8.tar.gz (73.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 MB 12.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: jpegio
#   Building wheel for jpegio (pyproject.toml) ... done
#   Created wheel for jpegio: filename=jpegio-0.2.8-cp313-cp313-linux_x86_64.whl size=1342185 sha256=772dc53716536fd3e7d100ab15eef3bf9c6cb4e3f671291207b8261703d2c016
#   Stored in directory: /root/.cache/pip/wheels/9e/1e/5c/ba4a3749847e3fbd60d86215f96b3329573329c7b832a62f09
# Successfully built jpegio
# Installing collected packages: jpegio
# Successfully installed jpegio-0.2.8

# %%
import torch
import torchvision
from pathlib import Path
from PIL import Image
import sys
import os
import shutil
from torchvision import transforms
import matplotlib.pyplot as plt
import torch.nn.functional as F


# dataloader
from torch.utils.data import Dataset, DataLoader, random_split

# jpeg
import jpegio as jio
import numpy as np
import tempfile
import matplotlib.pyplot as plt

# to store-reload best model
from contextlib import redirect_stdout
import io
import json
import gc
from collections import OrderedDict

# for testing
from torchvision.utils import save_image

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Base path
BASE_DIR = "/content/drive/MyDrive/Colab Notebooks/tesi/" if 'google.colab' in str(get_ipython()) else "."
NAME = "02_coefficients_steps"

# Directories
ZIP_PATH = os.path.join(BASE_DIR, "data", "img_align_celeba.zip")
LOCAL_DATA_ROOT = "/content/raw_data"
SRC_C_D = os.path.join(BASE_DIR, "src", "Cold-Diffusion-Models", "resolution-diffusion-pytorch", "resolution_diffusion_pytorch")

CHECKPOINT_DIR = os.path.join(BASE_DIR, "checkpoints", "coeff_truncation", NAME)
OUTPUT_DIR = os.path.join(BASE_DIR, "outputs", "trainings", "coeff_truncation", NAME)
TRAINED_MODEL_DIR = os.path.join(BASE_DIR, "trained_models", "cold_diffusion", "coeff_truncation", NAME)

save_path = os.path.join(TRAINED_MODEL_DIR, f'{NAME}.pt')

# importing the models
if SRC_C_D not in sys.path:
    sys.path.append(os.path.dirname(SRC_C_D))

# 6. Creazione cartelle
for path in [CHECKPOINT_DIR, OUTPUT_DIR, TRAINED_MODEL_DIR]:
    os.makedirs(path, exist_ok=True)

# %%
dataset_path = os.path.join(LOCAL_DATA_ROOT, "img_align_celeba")

# %%
if not os.path.exists(LOCAL_DATA_ROOT):
    print("Unzipping ...")
    # !unzip -q "{ZIP_PATH}" -d {LOCAL_DATA_ROOT}
    print("Done!")
else:
    print("Already unzipped")
# Out:
# Unzipping ...
# Done!

# %% [markdown]
# # Loading and PreProcessing

# %%
class CelebADataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.file_names = [f for f in os.listdir(root_dir) if f.endswith(('.jpg', '.jpeg'))]
        self.transform = transform

    def __len__(self):
        return len(self.file_names)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.file_names[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image

# Transform configuration
IMG_SIZE = 128
train_transform = transforms.Compose([
    transforms.CenterCrop(178),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Lambda(lambda x: (x * 2) - 1) # Normalize to [-1,1] for diffusion
])

batch_size_ = 8

# %%
# Loading dataset
full_dataset = CelebADataset(root_dir=dataset_path, transform=train_transform)

# Split random
train_size = int(0.9 * len(full_dataset))
test_size = len(full_dataset) - train_size
train_dataset, test_dataset = random_split(full_dataset, [train_size, test_size])

# DataLoaders
train_loader = DataLoader(train_dataset, batch_size=batch_size_, shuffle=True, num_workers=2, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size_, shuffle=False, num_workers=2)

print(f"Dataset ready. Train: {len(train_dataset)} | Test: {len(test_dataset)}")
# Out:
# Dataset ready. Train: 182339 | Test: 20260

# %%
def sanity_check_dataloader(dataloader):
    try:
        batch = next(iter(dataloader))
    except Exception as e:
        print(f"Error in loading batch: {e}")
        return

    print(f"Batch Shape: {batch.shape}")
    print(f"Range: Min={batch.min():.2f}, Max={batch.max():.2f}")

    img_t = batch[0]

    # Denormalize from [-1, 1] to [0, 1] for visualization
    img_viz = (img_t + 1) / 2
    img_viz = img_viz.clamp(0, 1)

    # Convert to [H, W, C] for matplotlib
    img_np = img_viz.permute(1, 2, 0).numpy()

    plt.figure(figsize=(5, 5))
    plt.imshow(img_np)
    plt.axis('off')
    plt.show()

sanity_check_dataloader(train_loader)
# Out:
# Batch Shape: torch.Size([8, 3, 128, 128])
# Range: Min=-1.00, Max=1.00

# %% [markdown]
# # Configuration

# %%
IMG_SIZE = 128
batch_size_ = 16

# %% [markdown]
# ### Defining the new degradation function

# %%
def zigzag():
  return [(i if s % 2 == 0 else s - i, s - i if s % 2 == 0 else i)
          for s in range(15)
          for i in range(s + 1)
          if (i < 8 and s - i < 8)]

print(zigzag())
# Out:
# [(0, 0), (1, 0), (0, 1), (0, 2), (1, 1), (2, 0), (3, 0), (2, 1), (1, 2), (0, 3), (0, 4), (1, 3), (2, 2), (3, 1), (4, 0), (5, 0), (4, 1), (3, 2), (2, 3), (1, 4), (0, 5), (0, 6), (1, 5), (2, 4), (3, 3), (4, 2), (5, 1), (6, 0), (7, 0), (6, 1), (5, 2), (4, 3), (3, 4), (2, 5), (1, 6), (0, 7), (1, 7), (2, 6), (3, 5), (4, 4), (5, 3), (6, 2), (7, 1), (7, 2), (6, 3), (5, 4), (4, 5), (3, 6), (2, 7), (3, 7), (4, 6), (5, 5), (6, 4), (7, 3), (7, 4), (6, 5), (5, 6), (4, 7), (5, 7), (6, 6), (7, 5), (7, 6), (6, 7), (7, 7)]

# %%
def _process_single_image(img_tensor, zigzag_to_zero):
    """
    Processes one single image at a time, to use less memory
    """

    img_np = ((img_tensor.detach().cpu().permute(1, 2, 0).numpy() + 1) * 127.5).clip(0, 255).astype(np.uint8)

    path_in = path_out = None
    try:
        with tempfile.NamedTemporaryFile(suffix=".jpg", delete=False) as f_in:
            path_in = f_in.name
            Image.fromarray(img_np).save(f_in, format='JPEG', quality=100, subsampling=0)

        del img_np  # to free space

        jpeg_struct = jio.read(path_in)

        for coef_array in jpeg_struct.coef_arrays:
            for i, j in zigzag_to_zero:
                coef_array[i::8, j::8] = 0

        fd, path_out = tempfile.mkstemp(suffix=".jpg")
        os.close(fd)
        jio.write(jpeg_struct, path_out)
        del jpeg_struct  # to free space

        with Image.open(path_out) as img_final:
            out_np = np.array(img_final.convert('RGB'), dtype=np.float32)

    finally:
        if path_in: os.unlink(path_in)
        if path_out: os.unlink(path_out)

    out_t = (torch.from_numpy(out_np).permute(2, 0, 1) / 127.5) - 1.0

    del out_np  # to free space
    return out_t


def jpegio_degradation(img_batch, step):
    device = img_batch.device
    batch_size = img_batch.shape[0]

    current_step = step.item() if torch.is_tensor(step) else step
    KEEP = 64 if current_step == 0 else max(1, 9 - (current_step - 1))
    zigzag_to_zero = zigzag()[KEEP:]

    out_tensors = []
    for b in range(batch_size):
        out_t = _process_single_image(img_batch[b], zigzag_to_zero)
        out_tensors.append(out_t)

    # to GPU just one time
    result = torch.stack(out_tensors).to(device)
    del out_tensors  # to free space
    return result

# %% [markdown]
# Now I configure the model using the classes of the authors

# %%
sys.argv = ['colab_kernel_launcher.py']

from resolution_diffusion_pytorch import Unet, GaussianDiffusion, Trainer

def find_last_checkpoint(save_folder):
    path = os.path.join(save_folder, f'model.pt')
    if os.path.exists(path):
        return path
    return None

# %%
from torch._prims_common import check
# --- CONFIGURATION ---
class Args:
    time_steps = 10
    train_steps = 5000
    save_folder = OUTPUT_DIR
    data_path = dataset_path
    checkpoint_path = CHECKPOINT_DIR
    load_path = find_last_checkpoint(checkpoint_path)
    train_routine = 'Final'
    resolution_routine = 'Incremental'
    sampling_routine = 'x0_step_down'
    image_size = IMG_SIZE
    channels = 3

args = Args()

# --- MODEL INITIALIZATION ---
model = Unet(
    dim = 64,
    dim_mults = (1, 2, 4, 8),
    channels = args.channels
).cuda()

diffusion = GaussianDiffusion(
    model,
    image_size = args.image_size,
    device_of_kernel = 'cuda',
    channels = args.channels,
    timesteps = args.time_steps,
    loss_type = 'l1',
    resolution_routine = args.resolution_routine,
    train_routine = args.train_routine,
    sampling_routine = args.sampling_routine
).cuda()

# Support for multiple GPUs if available
if torch.cuda.device_count() > 1:
    diffusion = torch.nn.DataParallel(diffusion)

class DummyWrapper(torch.nn.Module):
    def __init__(self, model):
        super().__init__()
        self.module = model

    def forward(self, *args, **kwargs):
        return self.module(*args, **kwargs)

    def __getattr__(self, name):
        try:
            return super().__getattr__(name)
        except AttributeError:
            return getattr(self.module, name)

# Apply wrapper
if not isinstance(diffusion, torch.nn.DataParallel):
    diffusion = DummyWrapper(diffusion)
    print("DummyWrapper aggiornato")


trainer = Trainer(
    diffusion,
    dataset_path,
    image_size = args.image_size,
    train_batch_size = 16,
    train_lr = 0.0001,
    train_num_steps = args.train_steps,
    ema_decay = 0.995,
    fp16 = False,
    results_folder = args.save_folder,
    load_path = args.load_path,
    save_and_sample_every = 25,
    gradient_accumulate_every = 2
    )
trainer.checkpoint_path = Path(args.checkpoint_path)
# Out:
# Is Time embed used ?  True
# DummyWrapper aggiornato
# Loading :  /content/drive/MyDrive/Colab Notebooks/tesi/checkpoints/coeff_truncation/02_coefficients_steps/model.pt

# %%
# --- OVERWRITING ---
inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion
inner_model.func = [lambda img, s=i: jpegio_degradation(img, s) for i in range(args.time_steps)]

# %% [markdown]
# ### Testing the new function

# %%
def show_degradation(img_path, steps_to_show):
    x_0_pil = Image.open(img_path)

    x_0_processed = train_transform(x_0_pil)
    x_0 = x_0_processed.unsqueeze(0).to('cuda')

    n_steps = len(steps_to_show)

    inner_model = diffusion

    # --- DEGRADATION ---
    print("Degradation (DCT)...")
    fig, axs = plt.subplots(1, n_steps, figsize=(15, 5))
    print(f"Range image: [{x_0.min()}, {x_0.max()}]")
    for i, t in enumerate(steps_to_show):
        with torch.no_grad():
            x_t = inner_model.q_sample(x_0, torch.tensor([t], device='cuda'))

        # From [-1, 1] to [0, 1] for visualization
        img_vis = ((x_t.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy()
        axs[i].imshow(img_vis.clip(0, 1))
        axs[i].set_title(f"Step t={t}")
        axs[i].axis('off')
    plt.show()


img_path = '/content/raw_data/img_align_celeba/000002.jpg'
steps_to_show = [i for i in range(args.time_steps)]
show_degradation(img_path, steps_to_show)
# Out:
# Degradation (DCT)...
# Range image: [-1.0, 1.0]

# %% [markdown]
# # Training
# ### helper functions

# %%
# psnr loss computation
def calculate_psnr(img1, img2):
    # from [-1, 1] to [0, 1] for PSNR computation
    img1 = (img1.detach() + 1.0) / 2.0
    img2 = (img2.detach() + 1.0) / 2.0
    mse = torch.mean((img1 - img2) ** 2)
    if mse == 0: return 100.0
    return (20 * torch.log10(1.0 / torch.sqrt(mse))).item()

# to reset the weights after each training
def weight_reset(m):
    """
    Goes through each layer of the model and resets the weights.
    """
    if isinstance(m, torch.nn.Conv2d) or isinstance(m, torch.nn.Linear):
        m.reset_parameters()
    if isinstance(m, torch.nn.BatchNorm2d):
        m.reset_parameters()

# %% [markdown]
# ### sanity check

# %%
models_to_patch = [diffusion, trainer.model, trainer.ema_model]

for model in models_to_patch:
    m = model.module if hasattr(model, 'module') else model
    m.func = [lambda img, s=i: jpegio_degradation(img, s) for i in range(args.time_steps)]
    print(f"Patched {type(m).__name__} — id: {id(m)} — func[0]: {m.func[0]}")
# Out:
# Patched GaussianDiffusion — id: 137022872363632 — func[0]: <function <lambda> at 0x7c9f0e126160>
# Patched GaussianDiffusion — id: 137022872363632 — func[0]: <function <lambda> at 0x7c9f1fa28680>
# Patched GaussianDiffusion — id: 137022850281744 — func[0]: <function <lambda> at 0x7c9f0e1263e0>

# %%
# Test q_sample on trainer.model directly
x_test = next(iter(trainer.dl)).cuda()[:1]
t_test = torch.tensor([5]).cuda()

m = trainer.model.module if hasattr(trainer.model, 'module') else trainer.model
x_deg = m.q_sample(x_test, t_test)
diff = (x_test - x_deg).abs().mean().item()
print(f"Differenza step 5 su trainer.model: {diff:.4f}")  # deve essere > 0

m_ema = trainer.ema_model.module if hasattr(trainer.ema_model, 'module') else trainer.ema_model
x_deg_ema = m_ema.q_sample(x_test, t_test)
diff_ema = (x_test - x_deg_ema).abs().mean().item()
print(f"Differenza step 5 su trainer.ema_model: {diff_ema:.4f}")  # deve essere > 0
# Out:
# Differenza step 5 su trainer.model: 0.0659
# Differenza step 5 su trainer.ema_model: 0.0659

# %% [markdown]
# ### checkpoints
# Overwriting the save and load functions so that I save also the optimizer's state and the losses:

# %%
def patched_save(self):
    data = {
        'step': self.step,
        'model': self.model.state_dict(),
        'ema': self.ema_model.state_dict(),
        'optimizer': self.opt.state_dict(),
        'losses': losses
    }

    # Convert checkpoint_path to Path object for proper path joining
    checkpoint_path_obj = Path(self.checkpoint_path)

    torch.save(data, str(checkpoint_path_obj / 'model.pt'))
    print(f"Saved checkpoint at step {self.step}")

def patched_load(self, load_path):
    print("Loading: ", load_path)
    data = torch.load(load_path)
    self.step = data['step']
    self.model.load_state_dict(data['model'])
    self.ema_model.load_state_dict(data['ema'])
    if 'optimizer' in data:
        self.opt.load_state_dict(data['optimizer'])
        print(f"Optimizer Loaded")
    if 'losses' in data:
        losses.extend(data['losses'])
        print(f"Loaded {len(losses)} previous losses")

# Rewriting modules
trainer.save = patched_save.__get__(trainer, type(trainer))
trainer.load = patched_load.__get__(trainer, type(trainer))

# %%
# Look for checkpoint
args.load_path = find_last_checkpoint(args.save_folder)
print(f"Found checkpoint: {args.load_path}")
# Out:
# Found checkpoint: None

# %% [markdown]
# ### Training

# %%
if TRAIN:
    losses = []
    temp_losses = []
    acc_step = trainer.gradient_accumulate_every
    # inner_model.apply(weight_reset)

    if isinstance(args, tuple):
        total_steps = args[0].train_steps
    else:
        total_steps = args.train_steps

    inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion

    # restoration
    if hasattr(inner_model, '_original_forward'):
        inner_model.forward = inner_model._original_forward
    else:
        inner_model._original_forward = inner_model.forward

    def forward_wrapper(*args_func, **kwargs_func):
        loss = inner_model._original_forward(*args_func, **kwargs_func)
        temp_losses.append(loss.item())

        if len(temp_losses) == acc_step:
            avg_loss = sum(temp_losses) / len(temp_losses)
            losses.append(avg_loss)
            temp_losses.clear()

        return loss

    inner_model.forward = forward_wrapper

    # Looking for checkpoints
    if args.load_path is not None and os.path.exists(args.load_path):
        trainer.load(args.load_path)
        print(f"Resumed from step {trainer.step}")
    else:
        print("Training from scratch")

    print(f"Training for {total_steps} steps")
    trainer.train()
    print("\n Training complete!")

# %% [markdown]
# ### Learning curve

# %%
if TRAIN:
    if len(losses) > 0:
        plt.figure(figsize=(10, 5))
        plt.plot(losses, label='Train Loss', color='#3498db', alpha=0.5)

        plt.title('Loss Curve')
        plt.xlabel('Step')
        plt.ylabel('Loss')
        plt.grid(True, alpha=.3)
        plt.legend()

        # saving the learning curve
        os.makedirs(args.save_folder, exist_ok=True)
        plt.savefig(f"{args.save_folder}/learning_curve.png")
        plt.show()
    else:
        print("No loss found, problems in training")

else:
    print("Skipping training, looking for saved learning curve.")
    learning_curve_path = f"{args.save_folder}/learning_curve.png"
    if os.path.exists(learning_curve_path):
        try:
            img = Image.open(learning_curve_path)
            plt.figure(figsize=(10, 5))
            plt.imshow(img)
            plt.title('Saved Loss Curve')
            plt.axis('off') # Hide axes for image
            plt.show()
        except Exception as e:
            print(f"Error loading or displaying saved learning curve: {e}")
    else:
        print(f"No saved learning curve found at {learning_curve_path}")
# Out:
# Skipping training, looking for saved learning curve.

# %% [markdown]
# ### Save model

# %%
if TRAIN:
    torch.save(diffusion.state_dict(), save_path)
    print(f"Model saved")

# %% [markdown]
# ### Reload model

# %%
if not TRAIN:
    trained_model = torch.load(save_path)

    new_state_dict = OrderedDict()
    for k, v in trained_model.items():
        new_key = k.replace('module.', '', 1)
        new_state_dict[new_key] = v

    inner_model = diffusion.module if hasattr(diffusion, 'module') else diffusion
    inner_model.load_state_dict(new_state_dict)

    inner_model.func = [lambda img, s=i: jpegio_dct_degradation(img, s) for i in range(args.time_steps)]

    diffusion.eval()
    print("Model loaded")
# Out:
# Model loaded

# %%
models_to_patch = [diffusion, trainer.model, trainer.ema_model]

for model in models_to_patch:
    m = model.module if hasattr(model, 'module') else model
    m.func = [lambda img, s=i: jpegio_degradation(img, s) for i in range(args.time_steps)]
    print(f"Patched {type(m).__name__} — id: {id(m)} — func[0]: {m.func[0]}")
# Out:
# Patched GaussianDiffusion — id: 137022872363632 — func[0]: <function <lambda> at 0x7c9f0e92eac0>
# Patched GaussianDiffusion — id: 137022872363632 — func[0]: <function <lambda> at 0x7c9f0e92efc0>
# Patched GaussianDiffusion — id: 137022850281744 — func[0]: <function <lambda> at 0x7c9f0e92f060>

# %% [markdown]
# ## Visualization
#
# Performing the degradation and reconstruction on an image

# %%
# --- PREPARATION ---
inner_model = diffusion

x_0_pil = Image.open(img_path)     # taking first image of the batch

# Apply the same preprocessing as for training data
preprocess = transforms.Compose([
    transforms.CenterCrop(178),
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
])
to_tensor = transforms.ToTensor()

x_0_processed = preprocess(x_0_pil)
x_0 = (to_tensor(x_0_processed) * 2) - 1 # Convert to tensor and normalize to [-1, 1]
x_0 = x_0.unsqueeze(0).to('cuda') # Add batch dimension and move to GPU

# visualization parameters
steps_to_show = [0, 3, 6, 9]
n_steps = len(steps_to_show)

# --- DEGRADATION ---
print("Degradation (DCT)...")
fig, axs = plt.subplots(1, n_steps, figsize=(15, 5))
for i, t in enumerate(steps_to_show):
    with torch.no_grad():
        x_t = inner_model.q_sample(x_0, torch.tensor([t], device='cuda'))

    # From [-1, 1] to [0, 1]
    print(f"Range of Image before plotting: {x_t.min()}, {x_t.max()}")
    img_vis = ((x_t.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy()
    axs[i].imshow(img_vis.clip(0, 1))
    axs[i].set_title(f"Degradation Step t={t}")
    axs[i].axis('off')
plt.show()


# --- RECONSTRUCTION ---
print("Reconstruction ...")

with torch.no_grad():
    xt, direct_recons,_img = inner_model.sample(batch_size=1, img=x_t)

    print(f"Range of Image reconstructed before plotting: {_img.min()}, {_img.max()}")
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Original Image
axs[0].imshow(((x_0.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[0].set_title("Original (x0)")

# Maximum degradation
axs[1].imshow(((xt.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[1].set_title("Degraded (t=9)")

# Reconstruction
axs[2].imshow(((_img.squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().numpy().clip(0, 1))
axs[2].set_title("Reconstructed")

for ax in axs: ax.axis('off')
plt.show()

psnr = calculate_psnr(x_0,_img)
print(f"PSNR: {psnr}")

l1_loss = F.l1_loss(_img, x_0).item()
print(f"L1 Loss: {l1_loss}")
# Out:
# Degradation (DCT)...
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 1.0
# Range of Image before plotting: -1.0, 0.9372549057006836
# Reconstruction ...
# Range of Image reconstructed before plotting: -1.1165138483047485, 1.0255223512649536
# PSNR: 22.24536895751953
# L1 Loss: 0.10751235485076904

# %% [markdown]
# # Test

# %%
if TEST:
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    results_psnr = []
    best_results = []
    worst_results = []

    max_test_images = 500
    processed_images = 0

    print(f"Starting testing on max {max_test_images} images...")

    diffusion.eval()

    with torch.no_grad():
        for batch in test_loader:
            if processed_images >= max_test_images:
                print("dropping last batch")
                break

            gt_tensor_norm = batch.to(device)
            curr_batch_size = min(gt_tensor_norm.shape[0], max_test_images - processed_images)
            gt_tensor_norm = gt_tensor_norm[:curr_batch_size]  # if necessary, truncates the last batch

            _, _, restored_norm = diffusion.sample(batch_size=curr_batch_size, img=gt_tensor_norm)

            # Convert to [0,1]
            gt_01 = (gt_tensor_norm + 1).mul_(0.5)
            restored_01 = (restored_norm + 1).mul_(0.5).clamp_(0, 1)

            # To CPU once for each batch
            gt_cpu = gt_01.cpu()
            restored_cpu = restored_01.cpu()

            # To free GPU
            del gt_tensor_norm, restored_norm, gt_01, restored_01
            torch.cuda.empty_cache()

            for b in range(curr_batch_size):
                single_gt = gt_cpu[b:b+1]
                single_restored = restored_cpu[b:b+1]

                psnr = calculate_psnr(single_gt, single_restored)
                results_psnr.append(psnr)

                current_res = {
                    'psnr': psnr,
                    'index': processed_images,
                    'restored': single_restored,
                    'gt': single_gt
                }

                # Best 5
                if len(best_results) < 5 or psnr > best_results[-1]['psnr']:
                    best_results.append(current_res)
                    best_results.sort(key=lambda x: x['psnr'], reverse=True)
                    best_results = best_results[:5]

                # Worst 5
                if len(worst_results) < 5 or psnr < worst_results[-1]['psnr']:
                    worst_results.append(current_res)
                    worst_results.sort(key=lambda x: x['psnr'])
                    worst_results = worst_results[:5]

                processed_images += 1
                print(f"Processing {processed_images}/{max_test_images} - PSNR: {psnr:.2f} dB")

            del gt_cpu, restored_cpu
            gc.collect()

    avg_psnr = sum(results_psnr) / len(results_psnr)
    print(f"\nTest completed")
    print(f"Mean PSNR over {processed_images} images: {avg_psnr:.2f} dB")
# Out:
# Starting testing on max 500 images...
# Processing 1/500 - PSNR: 31.69 dB
# Processing 2/500 - PSNR: 30.58 dB
# Processing 3/500 - PSNR: 27.42 dB
# Processing 4/500 - PSNR: 26.85 dB
# Processing 5/500 - PSNR: 31.24 dB
# Processing 6/500 - PSNR: 29.53 dB
# Processing 7/500 - PSNR: 31.34 dB
# Processing 8/500 - PSNR: 30.82 dB
# Processing 9/500 - PSNR: 30.00 dB
# Processing 10/500 - PSNR: 31.00 dB
# Processing 11/500 - PSNR: 32.41 dB
# Processing 12/500 - PSNR: 28.58 dB
# Processing 13/500 - PSNR: 29.88 dB
# Processing 14/500 - PSNR: 29.74 dB
# Processing 15/500 - PSNR: 30.20 dB
# Processing 16/500 - PSNR: 32.17 dB
# Processing 17/500 - PSNR: 28.70 dB
# Processing 18/500 - PSNR: 31.08 dB
# Processing 19/500 - PSNR: 28.62 dB
# Processing 20/500 - PSNR: 34.46 dB
# Processing 21/500 - PSNR: 31.23 dB
# Processing 22/500 - PSNR: 29.62 dB
# Processing 23/500 - PSNR: 30.67 dB
# Processing 24/500 - PSNR: 30.25 dB
# Processing 25/500 - PSNR: 30.84 dB
# Processing 26/500 - PSNR: 29.67 dB
# Processing 27/500 - PSNR: 30.52 dB
# Processing 28/500 - PSNR: 30.91 dB
# Processing 29/500 - PSNR: 28.75 dB
# Processing 30/500 - PSNR: 31.58 dB
# Processing 31/500 - PSNR: 30.00 dB
# Processing 32/500 - PSNR: 27.80 dB
# Processing 33/500 - PSNR: 32.69 dB
# Processing 34/500 - PSNR: 27.76 dB
# Processing 35/500 - PSNR: 31.74 dB
# Processing 36/500 - PSNR: 29.06 dB
# Processing 37/500 - PSNR: 29.91 dB
# Processing 38/500 - PSNR: 28.78 dB
# Processing 39/500 - PSNR: 29.56 dB
# Processing 40/500 - PSNR: 29.84 dB
# Processing 41/500 - PSNR: 29.12 dB
# Processing 42/500 - PSNR: 30.04 dB
# Processing 43/500 - PSNR: 30.65 dB
# Processing 44/500 - PSNR: 29.13 dB
# Processing 45/500 - PSNR: 29.85 dB
# Processing 46/500 - PSNR: 30.16 dB
# Processing 47/500 - PSNR: 31.07 dB
# Processing 48/500 - PSNR: 27.14 dB
# Processing 49/500 - PSNR: 32.03 dB
# Processing 50/500 - PSNR: 31.48 dB
# Processing 51/500 - PSNR: 34.37 dB
# Processing 52/500 - PSNR: 26.22 dB
# Processing 53/500 - PSNR: 33.50 dB
# Processing 54/500 - PSNR: 29.60 dB
# Processing 55/500 - PSNR: 29.79 dB
# Processing 56/500 - PSNR: 29.13 dB
# Processing 57/500 - PSNR: 30.00 dB
# Processing 58/500 - PSNR: 29.63 dB
# Processing 59/500 - PSNR: 32.73 dB
# Processing 60/500 - PSNR: 30.34 dB
# Processing 61/500 - PSNR: 30.65 dB
# Processing 62/500 - PSNR: 29.63 dB
# Processing 63/500 - PSNR: 31.68 dB
# Processing 64/500 - PSNR: 27.88 dB
# Processing 65/500 - PSNR: 30.92 dB
# Processing 66/500 - PSNR: 32.07 dB
# Processing 67/500 - PSNR: 29.02 dB
# Processing 68/500 - PSNR: 28.77 dB
# Processing 69/500 - PSNR: 31.83 dB
# Processing 70/500 - PSNR: 28.84 dB
# Processing 71/500 - PSNR: 27.32 dB
# Processing 72/500 - PSNR: 32.51 dB
# Processing 73/500 - PSNR: 31.87 dB
# Processing 74/500 - PSNR: 32.15 dB
# Processing 75/500 - PSNR: 33.06 dB
# Processing 76/500 - PSNR: 30.00 dB
# Processing 77/500 - PSNR: 31.46 dB
# Processing 78/500 - PSNR: 30.46 dB
# Processing 79/500 - PSNR: 29.38 dB
# Processing 80/500 - PSNR: 31.12 dB
# Processing 81/500 - PSNR: 30.48 dB
# Processing 82/500 - PSNR: 30.63 dB
# Processing 83/500 - PSNR: 31.47 dB
# Processing 84/500 - PSNR: 33.07 dB
# Processing 85/500 - PSNR: 24.41 dB
# Processing 86/500 - PSNR: 31.97 dB
# Processing 87/500 - PSNR: 30.58 dB
# Processing 88/500 - PSNR: 27.91 dB
# Processing 89/500 - PSNR: 32.10 dB
# Processing 90/500 - PSNR: 30.46 dB
# Processing 91/500 - PSNR: 30.86 dB
# Processing 92/500 - PSNR: 30.83 dB
# Processing 93/500 - PSNR: 30.28 dB
# Processing 94/500 - PSNR: 31.64 dB
# Processing 95/500 - PSNR: 28.36 dB
# Processing 96/500 - PSNR: 29.29 dB
# Processing 97/500 - PSNR: 27.12 dB
# Processing 98/500 - PSNR: 30.09 dB
# Processing 99/500 - PSNR: 32.63 dB
# Processing 100/500 - PSNR: 29.98 dB
# Processing 101/500 - PSNR: 27.43 dB
# Processing 102/500 - PSNR: 29.51 dB
# Processing 103/500 - PSNR: 30.24 dB
# Processing 104/500 - PSNR: 26.93 dB
# Processing 105/500 - PSNR: 30.46 dB
# Processing 106/500 - PSNR: 29.28 dB
# Processing 107/500 - PSNR: 35.19 dB
# Processing 108/500 - PSNR: 31.74 dB
# Processing 109/500 - PSNR: 29.28 dB
# Processing 110/500 - PSNR: 29.61 dB
# Processing 111/500 - PSNR: 30.22 dB
# Processing 112/500 - PSNR: 32.55 dB
# Processing 113/500 - PSNR: 30.91 dB
# Processing 114/500 - PSNR: 31.60 dB
# Processing 115/500 - PSNR: 30.24 dB
# Processing 116/500 - PSNR: 27.26 dB
# Processing 117/500 - PSNR: 30.39 dB
# Processing 118/500 - PSNR: 28.92 dB
# Processing 119/500 - PSNR: 32.54 dB
# Processing 120/500 - PSNR: 29.08 dB
# Processing 121/500 - PSNR: 33.00 dB
# Processing 122/500 - PSNR: 29.85 dB
# Processing 123/500 - PSNR: 31.69 dB
# Processing 124/500 - PSNR: 30.36 dB
# Processing 125/500 - PSNR: 30.02 dB
# Processing 126/500 - PSNR: 28.81 dB
# Processing 127/500 - PSNR: 30.47 dB
# Processing 128/500 - PSNR: 32.47 dB
# Processing 129/500 - PSNR: 32.01 dB
# Processing 130/500 - PSNR: 31.88 dB
# Processing 131/500 - PSNR: 32.63 dB
# Processing 132/500 - PSNR: 29.58 dB
# Processing 133/500 - PSNR: 28.98 dB
# Processing 134/500 - PSNR: 30.27 dB
# Processing 135/500 - PSNR: 31.96 dB
# Processing 136/500 - PSNR: 27.96 dB
# Processing 137/500 - PSNR: 29.68 dB
# Processing 138/500 - PSNR: 29.03 dB
# Processing 139/500 - PSNR: 31.16 dB
# Processing 140/500 - PSNR: 33.37 dB
# Processing 141/500 - PSNR: 32.78 dB
# Processing 142/500 - PSNR: 30.32 dB
# Processing 143/500 - PSNR: 31.95 dB
# Processing 144/500 - PSNR: 26.32 dB
# Processing 145/500 - PSNR: 31.82 dB
# Processing 146/500 - PSNR: 32.03 dB
# Processing 147/500 - PSNR: 30.05 dB
# Processing 148/500 - PSNR: 30.09 dB
# Processing 149/500 - PSNR: 34.06 dB
# Processing 150/500 - PSNR: 32.04 dB
# Processing 151/500 - PSNR: 28.72 dB
# Processing 152/500 - PSNR: 31.77 dB
# Processing 153/500 - PSNR: 31.27 dB
# Processing 154/500 - PSNR: 31.16 dB
# Processing 155/500 - PSNR: 29.37 dB
# Processing 156/500 - PSNR: 29.67 dB
# Processing 157/500 - PSNR: 28.00 dB
# Processing 158/500 - PSNR: 31.63 dB
# Processing 159/500 - PSNR: 28.59 dB
# Processing 160/500 - PSNR: 29.63 dB
# Processing 161/500 - PSNR: 28.91 dB
# Processing 162/500 - PSNR: 33.88 dB
# Processing 163/500 - PSNR: 33.51 dB
# Processing 164/500 - PSNR: 30.25 dB
# Processing 165/500 - PSNR: 32.10 dB
# Processing 166/500 - PSNR: 30.04 dB
# Processing 167/500 - PSNR: 29.71 dB
# Processing 168/500 - PSNR: 27.86 dB
# Processing 169/500 - PSNR: 29.30 dB
# Processing 170/500 - PSNR: 32.29 dB
# Processing 171/500 - PSNR: 29.08 dB
# Processing 172/500 - PSNR: 29.90 dB
# Processing 173/500 - PSNR: 32.99 dB
# Processing 174/500 - PSNR: 28.58 dB
# Processing 175/500 - PSNR: 30.87 dB
# Processing 176/500 - PSNR: 29.45 dB
# Processing 177/500 - PSNR: 28.59 dB
# Processing 178/500 - PSNR: 30.65 dB
# Processing 179/500 - PSNR: 26.77 dB
# Processing 180/500 - PSNR: 27.75 dB
# Processing 181/500 - PSNR: 26.34 dB
# Processing 182/500 - PSNR: 32.39 dB
# Processing 183/500 - PSNR: 25.71 dB
# Processing 184/500 - PSNR: 29.23 dB
# Processing 185/500 - PSNR: 29.45 dB
# Processing 186/500 - PSNR: 31.28 dB
# Processing 187/500 - PSNR: 30.40 dB
# Processing 188/500 - PSNR: 28.60 dB
# Processing 189/500 - PSNR: 30.38 dB
# Processing 190/500 - PSNR: 28.82 dB
# Processing 191/500 - PSNR: 32.54 dB
# Processing 192/500 - PSNR: 30.34 dB
# Processing 193/500 - PSNR: 32.22 dB
# Processing 194/500 - PSNR: 26.46 dB
# Processing 195/500 - PSNR: 29.53 dB
# Processing 196/500 - PSNR: 35.22 dB
# Processing 197/500 - PSNR: 29.78 dB
# Processing 198/500 - PSNR: 32.56 dB
# Processing 199/500 - PSNR: 30.05 dB
# Processing 200/500 - PSNR: 32.05 dB
# Processing 201/500 - PSNR: 31.72 dB
# Processing 202/500 - PSNR: 29.14 dB
# Processing 203/500 - PSNR: 33.26 dB
# Processing 204/500 - PSNR: 29.69 dB
# Processing 205/500 - PSNR: 27.81 dB
# Processing 206/500 - PSNR: 31.76 dB
# Processing 207/500 - PSNR: 33.27 dB
# Processing 208/500 - PSNR: 29.02 dB
# Processing 209/500 - PSNR: 29.74 dB
# Processing 210/500 - PSNR: 30.41 dB
# Processing 211/500 - PSNR: 29.87 dB
# Processing 212/500 - PSNR: 30.09 dB
# Processing 213/500 - PSNR: 29.94 dB
# Processing 214/500 - PSNR: 30.64 dB
# Processing 215/500 - PSNR: 28.22 dB
# Processing 216/500 - PSNR: 30.11 dB
# Processing 217/500 - PSNR: 29.75 dB
# Processing 218/500 - PSNR: 30.44 dB
# Processing 219/500 - PSNR: 32.17 dB
# Processing 220/500 - PSNR: 32.51 dB
# Processing 221/500 - PSNR: 29.90 dB
# Processing 222/500 - PSNR: 29.91 dB
# Processing 223/500 - PSNR: 31.64 dB
# Processing 224/500 - PSNR: 28.29 dB
# Processing 225/500 - PSNR: 27.49 dB
# Processing 226/500 - PSNR: 32.87 dB
# Processing 227/500 - PSNR: 31.82 dB
# Processing 228/500 - PSNR: 26.78 dB
# Processing 229/500 - PSNR: 31.35 dB
# Processing 230/500 - PSNR: 29.32 dB
# Processing 231/500 - PSNR: 31.36 dB
# Processing 232/500 - PSNR: 28.27 dB
# Processing 233/500 - PSNR: 28.70 dB
# Processing 234/500 - PSNR: 31.42 dB
# Processing 235/500 - PSNR: 29.44 dB
# Processing 236/500 - PSNR: 30.06 dB
# Processing 237/500 - PSNR: 31.65 dB
# Processing 238/500 - PSNR: 30.89 dB
# Processing 239/500 - PSNR: 31.87 dB
# Processing 240/500 - PSNR: 31.70 dB
# Processing 241/500 - PSNR: 28.55 dB
# Processing 242/500 - PSNR: 28.66 dB
# Processing 243/500 - PSNR: 31.72 dB
# Processing 244/500 - PSNR: 30.69 dB
# Processing 245/500 - PSNR: 30.01 dB
# Processing 246/500 - PSNR: 32.47 dB
# Processing 247/500 - PSNR: 26.45 dB
# Processing 248/500 - PSNR: 33.13 dB
# Processing 249/500 - PSNR: 28.50 dB
# Processing 250/500 - PSNR: 29.96 dB
# Processing 251/500 - PSNR: 30.75 dB
# Processing 252/500 - PSNR: 29.34 dB
# Processing 253/500 - PSNR: 31.20 dB
# Processing 254/500 - PSNR: 29.47 dB
# Processing 255/500 - PSNR: 27.38 dB
# Processing 256/500 - PSNR: 29.00 dB
# Processing 257/500 - PSNR: 30.81 dB
# Processing 258/500 - PSNR: 31.90 dB
# Processing 259/500 - PSNR: 33.55 dB
# Processing 260/500 - PSNR: 31.95 dB
# Processing 261/500 - PSNR: 33.23 dB
# Processing 262/500 - PSNR: 32.08 dB
# Processing 263/500 - PSNR: 31.56 dB
# Processing 264/500 - PSNR: 27.77 dB
# Processing 265/500 - PSNR: 30.59 dB
# Processing 266/500 - PSNR: 29.68 dB
# Processing 267/500 - PSNR: 30.44 dB
# Processing 268/500 - PSNR: 29.32 dB
# Processing 269/500 - PSNR: 29.59 dB
# Processing 270/500 - PSNR: 29.64 dB
# Processing 271/500 - PSNR: 28.16 dB
# Processing 272/500 - PSNR: 29.01 dB
# Processing 273/500 - PSNR: 31.75 dB
# Processing 274/500 - PSNR: 31.40 dB
# Processing 275/500 - PSNR: 32.00 dB
# Processing 276/500 - PSNR: 27.80 dB
# Processing 277/500 - PSNR: 31.65 dB
# Processing 278/500 - PSNR: 29.67 dB
# Processing 279/500 - PSNR: 31.42 dB
# Processing 280/500 - PSNR: 27.93 dB
# Processing 281/500 - PSNR: 30.27 dB
# Processing 282/500 - PSNR: 28.90 dB
# Processing 283/500 - PSNR: 25.90 dB
# Processing 284/500 - PSNR: 31.87 dB
# Processing 285/500 - PSNR: 29.57 dB
# Processing 286/500 - PSNR: 29.57 dB
# Processing 287/500 - PSNR: 29.45 dB
# Processing 288/500 - PSNR: 30.84 dB
# Processing 289/500 - PSNR: 30.50 dB
# Processing 290/500 - PSNR: 30.89 dB
# Processing 291/500 - PSNR: 30.63 dB
# Processing 292/500 - PSNR: 30.58 dB
# Processing 293/500 - PSNR: 34.58 dB
# Processing 294/500 - PSNR: 29.74 dB
# Processing 295/500 - PSNR: 31.04 dB
# Processing 296/500 - PSNR: 28.70 dB
# Processing 297/500 - PSNR: 28.96 dB
# Processing 298/500 - PSNR: 30.13 dB
# Processing 299/500 - PSNR: 30.03 dB
# Processing 300/500 - PSNR: 31.26 dB
# Processing 301/500 - PSNR: 31.33 dB
# Processing 302/500 - PSNR: 31.57 dB
# Processing 303/500 - PSNR: 30.96 dB
# Processing 304/500 - PSNR: 29.95 dB
# Processing 305/500 - PSNR: 29.55 dB
# Processing 306/500 - PSNR: 30.38 dB
# Processing 307/500 - PSNR: 31.45 dB
# Processing 308/500 - PSNR: 33.61 dB
# Processing 309/500 - PSNR: 30.07 dB
# Processing 310/500 - PSNR: 31.60 dB
# Processing 311/500 - PSNR: 30.41 dB
# Processing 312/500 - PSNR: 33.50 dB
# Processing 313/500 - PSNR: 30.27 dB
# Processing 314/500 - PSNR: 29.22 dB
# Processing 315/500 - PSNR: 29.14 dB
# Processing 316/500 - PSNR: 28.52 dB
# Processing 317/500 - PSNR: 33.89 dB
# Processing 318/500 - PSNR: 29.33 dB
# Processing 319/500 - PSNR: 31.66 dB
# Processing 320/500 - PSNR: 28.58 dB
# Processing 321/500 - PSNR: 28.91 dB
# Processing 322/500 - PSNR: 31.04 dB
# Processing 323/500 - PSNR: 30.27 dB
# Processing 324/500 - PSNR: 29.49 dB
# Processing 325/500 - PSNR: 31.71 dB
# Processing 326/500 - PSNR: 29.48 dB
# Processing 327/500 - PSNR: 32.47 dB
# Processing 328/500 - PSNR: 31.07 dB
# Processing 329/500 - PSNR: 33.09 dB
# Processing 330/500 - PSNR: 30.53 dB
# Processing 331/500 - PSNR: 34.63 dB
# Processing 332/500 - PSNR: 32.37 dB
# Processing 333/500 - PSNR: 31.42 dB
# Processing 334/500 - PSNR: 28.77 dB
# Processing 335/500 - PSNR: 27.63 dB
# Processing 336/500 - PSNR: 31.77 dB
# Processing 337/500 - PSNR: 33.63 dB
# Processing 338/500 - PSNR: 31.53 dB
# Processing 339/500 - PSNR: 29.24 dB
# Processing 340/500 - PSNR: 32.34 dB
# Processing 341/500 - PSNR: 33.97 dB
# Processing 342/500 - PSNR: 34.30 dB
# Processing 343/500 - PSNR: 31.83 dB
# Processing 344/500 - PSNR: 29.98 dB
# Processing 345/500 - PSNR: 29.05 dB
# Processing 346/500 - PSNR: 28.75 dB
# Processing 347/500 - PSNR: 25.09 dB
# Processing 348/500 - PSNR: 29.81 dB
# Processing 349/500 - PSNR: 29.91 dB
# Processing 350/500 - PSNR: 31.71 dB
# Processing 351/500 - PSNR: 31.93 dB
# Processing 352/500 - PSNR: 25.72 dB
# Processing 353/500 - PSNR: 30.63 dB
# Processing 354/500 - PSNR: 29.07 dB
# Processing 355/500 - PSNR: 30.24 dB
# Processing 356/500 - PSNR: 31.68 dB
# Processing 357/500 - PSNR: 31.13 dB
# Processing 358/500 - PSNR: 31.26 dB
# Processing 359/500 - PSNR: 32.88 dB
# Processing 360/500 - PSNR: 28.91 dB
# Processing 361/500 - PSNR: 27.18 dB
# Processing 362/500 - PSNR: 31.74 dB
# Processing 363/500 - PSNR: 30.46 dB
# Processing 364/500 - PSNR: 28.98 dB
# Processing 365/500 - PSNR: 25.89 dB
# Processing 366/500 - PSNR: 31.19 dB
# Processing 367/500 - PSNR: 29.20 dB
# Processing 368/500 - PSNR: 31.30 dB
# Processing 369/500 - PSNR: 30.07 dB
# Processing 370/500 - PSNR: 30.35 dB
# Processing 371/500 - PSNR: 28.96 dB
# Processing 372/500 - PSNR: 32.96 dB
# Processing 373/500 - PSNR: 29.04 dB
# Processing 374/500 - PSNR: 30.87 dB
# Processing 375/500 - PSNR: 28.61 dB
# Processing 376/500 - PSNR: 29.62 dB
# Processing 377/500 - PSNR: 29.46 dB
# Processing 378/500 - PSNR: 29.95 dB
# Processing 379/500 - PSNR: 30.51 dB
# Processing 380/500 - PSNR: 31.61 dB
# Processing 381/500 - PSNR: 31.91 dB
# Processing 382/500 - PSNR: 30.71 dB
# Processing 383/500 - PSNR: 32.12 dB
# Processing 384/500 - PSNR: 25.80 dB
# Processing 385/500 - PSNR: 29.91 dB
# Processing 386/500 - PSNR: 30.68 dB
# Processing 387/500 - PSNR: 27.05 dB
# Processing 388/500 - PSNR: 30.50 dB
# Processing 389/500 - PSNR: 30.43 dB
# Processing 390/500 - PSNR: 30.70 dB
# Processing 391/500 - PSNR: 30.15 dB
# Processing 392/500 - PSNR: 30.52 dB
# Processing 393/500 - PSNR: 29.99 dB
# Processing 394/500 - PSNR: 27.86 dB
# Processing 395/500 - PSNR: 30.17 dB
# Processing 396/500 - PSNR: 29.49 dB
# Processing 397/500 - PSNR: 28.44 dB
# Processing 398/500 - PSNR: 29.40 dB
# Processing 399/500 - PSNR: 30.31 dB
# Processing 400/500 - PSNR: 29.25 dB
# Processing 401/500 - PSNR: 29.85 dB
# Processing 402/500 - PSNR: 28.86 dB
# Processing 403/500 - PSNR: 31.32 dB
# Processing 404/500 - PSNR: 30.24 dB
# Processing 405/500 - PSNR: 29.62 dB
# Processing 406/500 - PSNR: 27.76 dB
# Processing 407/500 - PSNR: 29.26 dB
# Processing 408/500 - PSNR: 27.84 dB
# Processing 409/500 - PSNR: 27.63 dB
# Processing 410/500 - PSNR: 30.63 dB
# Processing 411/500 - PSNR: 29.45 dB
# Processing 412/500 - PSNR: 28.34 dB
# Processing 413/500 - PSNR: 31.62 dB
# Processing 414/500 - PSNR: 32.93 dB
# Processing 415/500 - PSNR: 31.56 dB
# Processing 416/500 - PSNR: 30.64 dB
# Processing 417/500 - PSNR: 31.51 dB
# Processing 418/500 - PSNR: 30.45 dB
# Processing 419/500 - PSNR: 28.78 dB
# Processing 420/500 - PSNR: 31.91 dB
# Processing 421/500 - PSNR: 29.80 dB
# Processing 422/500 - PSNR: 33.29 dB
# Processing 423/500 - PSNR: 34.75 dB
# Processing 424/500 - PSNR: 29.99 dB
# Processing 425/500 - PSNR: 32.18 dB
# Processing 426/500 - PSNR: 30.08 dB
# Processing 427/500 - PSNR: 29.12 dB
# Processing 428/500 - PSNR: 27.03 dB
# Processing 429/500 - PSNR: 32.57 dB
# Processing 430/500 - PSNR: 29.89 dB
# Processing 431/500 - PSNR: 30.34 dB
# Processing 432/500 - PSNR: 28.28 dB
# Processing 433/500 - PSNR: 30.44 dB
# Processing 434/500 - PSNR: 27.94 dB
# Processing 435/500 - PSNR: 28.81 dB
# Processing 436/500 - PSNR: 30.88 dB
# Processing 437/500 - PSNR: 32.01 dB
# Processing 438/500 - PSNR: 29.34 dB
# Processing 439/500 - PSNR: 28.18 dB
# Processing 440/500 - PSNR: 29.67 dB
# Processing 441/500 - PSNR: 27.19 dB
# Processing 442/500 - PSNR: 29.51 dB
# Processing 443/500 - PSNR: 30.39 dB
# Processing 444/500 - PSNR: 32.40 dB
# Processing 445/500 - PSNR: 29.37 dB
# Processing 446/500 - PSNR: 31.14 dB
# Processing 447/500 - PSNR: 29.94 dB
# Processing 448/500 - PSNR: 31.13 dB
# Processing 449/500 - PSNR: 30.71 dB
# Processing 450/500 - PSNR: 25.99 dB
# Processing 451/500 - PSNR: 26.94 dB
# Processing 452/500 - PSNR: 27.11 dB
# Processing 453/500 - PSNR: 31.20 dB
# Processing 454/500 - PSNR: 31.59 dB
# Processing 455/500 - PSNR: 30.28 dB
# Processing 456/500 - PSNR: 29.64 dB
# Processing 457/500 - PSNR: 31.19 dB
# Processing 458/500 - PSNR: 32.38 dB
# Processing 459/500 - PSNR: 28.70 dB
# Processing 460/500 - PSNR: 33.13 dB
# Processing 461/500 - PSNR: 30.37 dB
# Processing 462/500 - PSNR: 28.11 dB
# Processing 463/500 - PSNR: 29.54 dB
# Processing 464/500 - PSNR: 30.46 dB
# Processing 465/500 - PSNR: 30.35 dB
# Processing 466/500 - PSNR: 30.58 dB
# Processing 467/500 - PSNR: 30.56 dB
# Processing 468/500 - PSNR: 30.31 dB
# Processing 469/500 - PSNR: 30.15 dB
# Processing 470/500 - PSNR: 33.31 dB
# Processing 471/500 - PSNR: 29.52 dB
# Processing 472/500 - PSNR: 31.79 dB
# Processing 473/500 - PSNR: 30.31 dB
# Processing 474/500 - PSNR: 28.30 dB
# Processing 475/500 - PSNR: 32.61 dB
# Processing 476/500 - PSNR: 31.60 dB
# Processing 477/500 - PSNR: 32.30 dB
# Processing 478/500 - PSNR: 31.43 dB
# Processing 479/500 - PSNR: 29.59 dB
# Processing 480/500 - PSNR: 29.58 dB
# Processing 481/500 - PSNR: 28.63 dB
# Processing 482/500 - PSNR: 30.54 dB
# Processing 483/500 - PSNR: 32.22 dB
# Processing 484/500 - PSNR: 29.64 dB
# Processing 485/500 - PSNR: 29.05 dB
# Processing 486/500 - PSNR: 29.74 dB
# Processing 487/500 - PSNR: 31.37 dB
# Processing 488/500 - PSNR: 29.31 dB
# Processing 489/500 - PSNR: 29.60 dB
# Processing 490/500 - PSNR: 31.89 dB
# Processing 491/500 - PSNR: 29.65 dB
# Processing 492/500 - PSNR: 30.68 dB
# Processing 493/500 - PSNR: 30.82 dB
# Processing 494/500 - PSNR: 28.11 dB
# Processing 495/500 - PSNR: 30.66 dB
# Processing 496/500 - PSNR: 28.74 dB
# Processing 497/500 - PSNR: 29.59 dB
# Processing 498/500 - PSNR: 31.32 dB
# Processing 499/500 - PSNR: 29.10 dB
# Processing 500/500 - PSNR: 27.47 dB
# dropping last batch
#
# Test completed
# Mean PSNR over 500 images: 30.29 dB

# %%
if TEST:
    for batch in test_loader:
        gt_tensor_norm = batch.to(device)
        curr_batch_size = min(gt_tensor_norm.shape[0], max_test_images - processed_images)
        print(f"batch shape: {gt_tensor_norm.shape}")
        print(f"curr_batch_size: {curr_batch_size}")
        print(f"processed_images: {processed_images}")
        break
# Out:
# batch shape: torch.Size([8, 3, 128, 128])
# curr_batch_size: 0
# processed_images: 500

# %%
if TEST:
    print(f"Media PSNR: {np.mean(results_psnr):.2f}")

    worst_5_psnr_values = [f"{item['psnr']:.2f}" for item in worst_results[:5]]
    print(f"Worst 5 PSNR: {', '.join(worst_5_psnr_values)}")

    best_5_psnr_values = [f"{item['psnr']:.2f}" for item in best_results[:5]]
    print(f"Best 5 PSNR: {', '.join(best_5_psnr_values)}")
# Out:
# Media PSNR: 30.29
# Worst 5 PSNR: 24.41, 25.09, 25.71, 25.72, 25.80
# Best 5 PSNR: 35.22, 35.19, 34.75, 34.63, 34.58

# %%
# BEST
if TEST:
    b = best_results[0]

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title(f"Originale")
    plt.imshow(b['gt'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    # Normalize b['gt'] from [0, 1] to [-1, 1] before passing to jpegio_degradation
    normalized_gt = (b['gt'] * 2) - 1
    b['degraded'] = jpegio_degradation(normalized_gt, 9)

    plt.subplot(1, 3, 2)
    plt.title(f"Degradata (Input)")
    # Denormalize for display: from [-1, 1] back to [0, 1]
    img_display = ((b['degraded'].squeeze().permute(1, 2, 0) + 1) * 0.5).cpu().detach().clamp(0, 1)
    plt.imshow(img_display)

    plt.subplot(1, 3, 3)
    plt.title(f"Restaurata (Output) - PSNR: {b['psnr']:.2f}")
    plt.imshow(b['restored'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    plt.show()

# %%
# WORST
if TEST:
    w = worst_results[0]

    plt.figure(figsize=(15, 5))
    plt.subplot(1, 3, 1)
    plt.title(f"Originale")
    plt.imshow(w['gt'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))

    w['degraded'] = jpegio_degradation(w['gt'], 9)

    plt.subplot(1, 3, 2)
    plt.title(f"Degradata (Input)")
    plt.imshow((w['degraded'].squeeze()).permute(1, 2, 0).cpu().detach().clamp(0, 1))

    plt.subplot(1, 3, 3)
    plt.title(f"Restaurata (Output) - PSNR: {w['psnr']:.2f}")
    plt.imshow(w['restored'].squeeze().permute(1, 2, 0).cpu().detach().clamp(0, 1))
    plt.show()

# %%
def plot_train_recons(index):
    recon_path = os.path.join(OUTPUT_DIR, f"sample-recon-{index}.png")
    direct_recon_path = os.path.join(OUTPUT_DIR, f"sample-direct_recons-{index}.png")
    degradated_path = os.path.join(OUTPUT_DIR, f"sample-xt-{index}.png")
    original_path = os.path.join(OUTPUT_DIR, f"sample-og-{index}.png")

    fig, axs = plt.subplots(4, 1, figsize=(15, 20))

    # Load images as tensors
    original_img = Image.open(original_path)
    degradated_img = Image.open(degradated_path)
    recon_img = Image.open(recon_path)
    direct_recon_img = Image.open(direct_recon_path)

    # Original Image
    axs[0].imshow(original_img)
    axs[0].set_title(f"Original (x0) - Index {index}")

    # Maximum degradation
    axs[1].imshow(degradated_img)
    axs[1].set_title(f"Degraded (t=9) - Index {index}")

    # Reconstruction
    axs[2].imshow(recon_img)
    axs[2].set_title(f"Reconstructed - Index {index}")

    # Direct Reconstruction (assuming this refers to direct_recon_path)
    axs[3].imshow(direct_recon_img)
    axs[3].set_title(f"Direct Reconstructed - Index {index}")

    for ax in axs: ax.axis('off')
    plt.tight_layout()
    plt.show()

print(f"Prima ricostruzione")
plot_train_recons(199)
# Out:
# Prima ricostruzione
